# %% [markdown]
# ### 0. Runtime sanity check
# <small>
# Эта ячейка нужна для самого первого вопроса: я вообще в правильной среде или нет?
#
# Что она проверяет:
# - текущую рабочую директорию,
# - имя хоста,
# - есть ли **CUDA**,
# - виден ли `/content`,
# - не сижу ли я случайно в локальной машине вместо **Colab** runtime,
# - версию **Python**,
# - версию **Torch**,
# - **CUDA** runtime,
# - имя **GPU**,
# - число доступных **CPU**.
#
# Это просто диагностическая ячейка перед любыми действиями.
# Если здесь нет **GPU** или нет `/content`, дальше запускать пайплайн бессмысленно.
# </small>

# %%
import os, sys, socket, torch, pathlib, shutil, subprocess, textwrap
print("cwd:", os.getcwd())
print("host:", socket.gethostname())
print("cuda:", torch.cuda.is_available())
print("content exists:", pathlib.Path("/content").exists())
print("local project exists:", pathlib.Path("/home/yaroslav").exists())
print("Python:", sys.version)
print("Executable:", sys.executable)
print("Torch version:", torch.__version__)
print("CUDA version :", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("CPU cores visible:", os.cpu_count())
# Out:
# cwd: /content
# host: 7808ba0ac9b4
# cuda: True
# content exists: True
# local project exists: False
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Executable: /usr/bin/python3
# Torch version: 2.10.0+cu128
# CUDA version : 12.8
# CUDA available: True
# GPU name: Tesla T4
# CPU cores visible: 2

# %% [markdown]
# ### 1. Mount Google Drive
# <small>
# Проектовый репозиторий, старые <code>runs/</code>, архив **PDBBind** и <code>esm_cache/</code> лежат на **Google Drive**.
#
# Эта ячейка просто подключает **Drive** к runtime, чтобы дальше можно было:
# - подтянуть свежий код,
# - скопировать нужные файлы в `/content`,
# - потом вернуть артефакты обратно на **Drive**.
#
# Важно: тренировка идет не на **Drive**, а в `/content`.
# **Drive** здесь используется как долговременное хранилище, а не как рабочая файловая система для обучения.
# </small>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. Imports for notebook orchestration
# <small>
# Здесь только те импорты, которые нужны самому ноутбуку как "пульту управления":
#
# - менять директории,
# - запускать фоновые процессы,
# - смотреть версию **Torch**.
#
# Логика обучения, датасетов и моделей здесь не живет.
# Она уже вынесена в проектные файлы и в `scripts/`.
# </small>

# %%
import os
import subprocess
import torch

# %% [markdown]
# ### 3. Define paths and refresh the Drive-side repo
# <small>
# Здесь задаются две важные директории:
#
# - `SRC` — репозиторий на **Google Drive**,
# - `DST` — временная рабочая копия в `/content`.
#
# Почему так:
# - код и обучение лучше держать в `/content`, потому что это быстрее и стабильнее,
# - **Drive** остается местом хранения, а не местом активной работы.
#
# Также здесь делается:
# - переход в `SRC`,
# - `git checkout -- config.json` чтобы сбросить временные правки в конфиге,
# - `git pull` чтобы подтянуть свежий код.
#
# Смысл простой: на **Drive** лежит "источник истины", а в `/content` каждый запуск собирается свежая рабочая копия.
# </small>

# %%
SRC = "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs"
DST = "/content/DUMPLINGs"

LOCAL_RUNS = f"{DST}/runs"
DRIVE_RUNS = f"{SRC}/runs"

LOCAL_FEATURES = f"{DST}/protein_context_features"
DRIVE_FEATURES = f"{SRC}/protein_context_features"

os.chdir(SRC)

status = subprocess.run(["git", "status", "--short"], capture_output=True, text=True, check=True,)
if status.stdout.strip():
    raise RuntimeError("Working tree is dirty before git pull:\n" + status.stdout)
subprocess.run(["git", "pull", "--ff-only"], check=True,)
# Out:
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 28 (delta 22), reused 24 (delta 18), pack-reused 0 (from 0)
# Unpacking objects: 100% (28/28), 21.84 KiB | 4.00 KiB/s, done.
# From https://github.com/BlackSabbitch/DUMPLINGs
#    22a6d0d..5edd5c0  main       -> origin/main
# Updating 22a6d0d..5edd5c0
# error: Your local changes to the following files would be overwritten by merge:
# 	scripts/colab_stage_workspace.py
# Please commit your changes or stash them before you merge.
# Aborting

# %% [markdown]
# ### 4. Stage the workspace into `/content`
# <small>
# Это одна из самых важных стадий.
#
# Скрипт:
# - пересоздает рабочую папку `DST`,
# - копирует туда только нужные проектные файлы,
# - копирует `esm_cache/`, если он уже есть на **Drive**,
# - копирует архив `pdbbind_v2016.tar.gz`.
#
# Зачем это нужно:
# - не работать напрямую из **Google Drive**,
# - не тянуть за собой весь возможный мусор,
# - иметь чистую воспроизводимую рабочую копию на каждый run.
#
# То есть после этой ячейки `/content/DUMPLINGs` — это реальное место, из которого будет запускаться эксперимент.
# </small>

# %%
# !python scripts/colab_stage_workspace.py \
  --src "{SRC}" \
  --dst "{DST}" \
  --drive-runs "{DRIVE_RUNS}"
# Out:
# Copied protein context features from /content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/protein_context_features (2579 top-level entries, source=protein_context_features)
# Copied archive to /content/DUMPLINGs/pdbbind_v2016.tar.gz
# Workspace staged into /content/DUMPLINGs

# %% [markdown]
# ### 5. Enter the staged workspace
# <small>
# После копирования мы явно переходим в <code>DST</code>.
#
# Это важно, потому что дальше:
# - `run.sh`,
# - `run.py`,
# - относительные пути вроде `datasets/`, `runs/`, `esm_cache/`
#
# должны разрешаться именно внутри `/content/DUMPLINGs`, а не где-то еще.
# </small>

# %%
os.chdir(DST)
print(os.getcwd())
# Out:
# /content/DUMPLINGs

# %% [markdown]
# ### 6. Install ordinary project requirements
# <small>
# Эта ячейка ставит обычные зависимости проекта из <code>requirements.txt</code>.
#
# Сюда относятся, например:
# - `pandas`
# - `tqdm`
# - `matplotlib`
# - `biopython`
# - `rdkit`
# - `fair-esm`
# - `uniplot`
#
# Почему это вынесено в отдельный шаг:
# - это обычные project dependencies,
# - они логически отличаются от **PyG/Torch-Geometric** стека,
# - их удобнее диагностировать отдельно.
#
# Важно: здесь не ставится специальный **CUDA/PyG** стек.
# Он ставится следующим шагом отдельным скриптом, потому что там нужна привязка к конкретным версиям **Torch** и **CUDA** в **Colab** runtime.
# </small>

# %%
# !python scripts/colab_install_requirements.py
# Out:
# Requirements file: requirements.txt
# Skipping prefixes:
#   - torch
#   - torch-geometric
#   - torch-scatter
#   - torch-sparse
#   - torch-cluster
#   - pyg-lib
# Installing filtered requirements:
#   - rdkit
#   - biopython
#   - pandas
#   - tqdm
#   - matplotlib
#   - uniplot
#   - fair-esm
# Collecting rdkit
#   Downloading rdkit-2026.3.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting biopython
#   Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting uniplot
#   Downloading uniplot-0.21.5-py3-none-any.whl.metadata (17 kB)
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Collecting readchar>=4.2.1 (from uniplot)
#   Downloading readchar-4.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading rdkit-2026.3.1-cp312-cp312-manylinux_2_28_x86_64.whl (37.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 14.4 MB/s eta 0:00:00:00:0100:01
# Downloading biopython-1.87-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.1 MB/s eta 0:00:00a 0:00:01
# Downloading uniplot-0.21.5-py3-none-any.whl (37 kB)
# Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.7 MB/s eta 0:00:00
# Downloading readchar-4.2.2-py3-none-any.whl (9.4 kB)
# Installing collected packages: fair-esm, readchar, rdkit, biopython, uniplot
# Successfully installed biopython-1.87 fair-esm-2.0.0 rdkit-2026.3.1 readchar-4.2.2 uniplot-0.21.5

# %% [markdown]
# ### 7. Install Colab-specific PyG dependencies
# <small>
# Эта стадия не про сам проект, а про среду выполнения.
#
# Скрипт:
# - определяет текущую версию **Torch** и **CUDA** в runtime,
# - подбирает правильный wheel index для **PyG**,
# - сносит потенциально несовместимые старые пакеты,
# - ставит совместимые `pyg-lib`, `torch-scatter`, `torch-sparse`, `torch-cluster`, `torch-geometric`,
# - делает небольшую проверку, что **CUDA**-часть действительно работает.
#
# Это именно **Colab** bootstrap.
# В обычной локальной среде такой шаг может не понадобиться.
# </small>

# %%
# !python scripts/colab_install_pyg.py
# Out:
# PyG wheel index: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# $ pip uninstall -y pyg-lib torch-scatter torch-sparse torch-cluster torch-geometric || true
# WARNING: Skipping pyg-lib as it is not installed.
# WARNING: Skipping torch-scatter as it is not installed.
# WARNING: Skipping torch-sparse as it is not installed.
# WARNING: Skipping torch-cluster as it is not installed.
# WARNING: Skipping torch-geometric as it is not installed.
# $ pip install pyg-lib torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Collecting pyg-lib
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/pyg_lib-0.6.0%2Bpt210cu128-cp312-cp312-manylinux_2_28_x86_64.whl (49.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.4 MB/s eta 0:00:0000:0100:01
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_scatter-2.1.2%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 125.4 MB/s eta 0:00:0000:0100:01
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_sparse-0.6.18%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 123.3 MB/s eta 0:00:0000:01
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_cluster-1.6.3%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 101.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch-sparse) (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy->torch-sparse) (2.0.2)
# Installing collected packages: torch-scatter, pyg-lib, torch-sparse, torch-cluster
# Successfully installed pyg-lib-0.6.0+pt210cu128 torch-cluster-1.6.3+pt210cu128 torch-scatter-2.1.2+pt210cu128 torch-sparse-0.6.18+pt210cu128
# $ pip install torch-geometric
# Collecting torch-geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.13.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.15.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.7.0
# torch_sparse: /usr/local/lib/python3.12/dist-packages/torch_sparse/__init__.py
# torch_sparse CUDA check OK: cuda:0
#
# Recommended Colab workflow:
# 1. Keep the repo and training outputs in /content while running.
# 2. Copy final runs/ and cached artifacts back to Drive after training.
# 3. Avoid heavy read/write loops directly on mounted Google Drive.

# %% [markdown]
# ### 8. Re-check Torch and CUDA after dependency setup
# <small>
# После установки **PyG** полезно еще раз увидеть:
#
# - что **Torch** жив,
# - что **CUDA** по-прежнему доступна,
# - что версия **CUDA** выглядит ожидаемо.
#
# Это не обязательная ячейка, но удобная контрольная точка, если потом что-то идет странно.
# </small>

# %%
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("cuda version:", torch.version.cuda)
# Out:
# torch: 2.10.0+cu128
# cuda available: True
# cuda version: 12.8

# %% [markdown]
# ### 9. Start background sync for `runs/`
# <small>
# Во время обучения <code>runs/</code> стоит периодически синкать обратно на **Drive**.
#
# Зачем:
# - если runtime упадет,
# - если браузер/сессия отвалится,
# - если **Colab** решит закончить жизнь раньше, чем хотелось,
#
# то хотя бы часть логов и артефактов уже будет на **Drive**.
#
# Почему здесь синкается только `runs/`, а не `esm_cache/`:
# - `runs/` постоянно пополняется логами, history, checkpoint-ами,
# - `esm_cache/` в обычной жизни достаточно:
#   - скопировать в начале,
#   - и один раз вернуть в конце.
#
# То есть `runs/` — это живой поток артефактов,
# а `esm_cache/` — накопительный кэш, который обычно не требует постоянной синхронизации.
# </small>

# %%
sync_proc = subprocess.Popen([
    "bash",
    "scripts/colab_start_sync.sh",
    LOCAL_RUNS,
    DRIVE_RUNS,
])
print("Sync PID:", sync_proc.pid)
# Out:
# Sync PID: 4490

# %% [markdown]
# ### 10. Launch the experiment
# <small>
# Это уже собственно запуск проекта.
#
# Мы:
# - делаем `run.sh` исполняемым,
# - запускаем его с `--extract`.
#
# Что означает `--extract`:
# - перед построением датасета будет выполнена распаковка/подготовка исходного архива.
#
# Если extraction не нужен, можно запускать просто `./run.sh`.
#
# Важно: к этому моменту весь подготовительный orchestration уже должен быть завершен.
# После этой ячейки начинает работать сам проектный pipeline.
# </small>

# %%
# !chmod +x run.sh

# !python scripts/cluster_make_smoke_config.py \
  --base-config config.json \
  --output tmp/colab_smoke_a1.json \
  --experiment-name DUMPLING_colab_smoke \
  --model-family A1 \
  --protein-context-mode none \
  --ligand-context-mode none \
  --epochs 2 \
  --batch-size 2 \
  --num-workers 0

# !./run.sh --config tmp/colab_smoke_a1.json --n-times 3 --rseed 42

# !./run.sh --extract # --a3-mixer-bias # --no-a3-mixer-bias
# Out:
# [INFO][EXPERIMENT] Starting experiment: DUMPLING_A2_first_run
# [INFO][EXPERIMENT] ============================================= *** STAGE: INITIALIZING *** ==============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Experiment signature: DUMPLING_A2_first_run_20260510_041820
# [INFO][EXPERIMENT] Base Datasets folder: datasets
# [INFO][EXPERIMENT] Base protein context features folder: protein_context_features
# [INFO][EXPERIMENT] Base ligand context features folder: ligand_context_features
# [INFO][EXPERIMENT] Run results folder: runs/DUMPLING_A2_first_run_20260510_041820
# [INFO][EXPERIMENT] Log file: runs/DUMPLING_A2_first_run_20260510_041820/log.txt
# [INFO][EXPERIMENT] ================================================ *** STAGE: DATASET *** ================================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][InteractionGraphParser] Initialized dist_threshold=5.0, ca_only=False
# [INFO][CNNParser] Initialized is_ligand=False
# [INFO][CNNParser] Initialized is_ligand=True
# [INFO][REGISTRY] Loaded bad complexes registry from bad_complexes.toml with 2 entries
# [INFO][EXPERIMENT] Preparing extraction for subset 'refined'.
# [INFO][EXTRACTION] Unpacking 4057 complexes.
# Extracting refined: 66444file [00:57, 1147.03file/s]
# [DEBUG][EXTRACTION] Unpacking completed.
# [DEBUG][EXPERIMENT] Extraction for subset 'refined' completed in 1m 47.1s
# [INFO][EXPERIMENT] Preparing dataset build for subset 'refined'.
# [WARNING][REGISTRY] Excluded 2 complexes from subset refined using bad_complexes.toml: 4bps(training), 2iw4(training)
# [INFO][BUILD] Starting parallel parsing on 2 cores.
#  63%|██████▎   | 2546/4055 [01:28<01:21, 18.50it/s][WARNING][CNNParser] Ligand processing failed: Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8
# 100%|██████████| 4055/4055 [02:17<00:00, 29.40it/s]
# [INFO][BUILD] Success: 4054, Errors: 1
# [WARNING][BUILD] Errors: Counter({"ligand_context_error: Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 8": 1})
# [INFO][SAVE] Dataset saved to datasets/pdbbds_ref_DimeNet_interaction5p0_cef4c2f5381066ae5aef757756bf284a.pickle (compression: None)
# [INFO][SAVE] Metadata saved to datasets/pdbbds_ref_DimeNet_interaction5p0_cef4c2f5381066ae5aef757756bf284a_meta.json
# [DEBUG][EXPERIMENT] Dataset build for subset 'refined' completed in 2m 37.4s
# [INFO][SPLIT] Preparing train/val/test split.
# [INFO][SPLIT] Core as test: True
# [WARNING][DATASET] 1 core complexes are missing from refined dataset
# [INFO][SPLIT] Strategy: random
# [DEBUG][SPLIT] Total: 3765 | Train: 3201 | Val: 564
# [DEBUG][SPLIT] Train/val/test split completed in 0.0s
# [INFO][EXPERIMENT] Prepared splits | Train: 3201 | Val: 564 | Test: 289
# [INFO][NORMALIZATION] Preparing data normalization.
# [DEBUG][NORMALIZATION] Data normalization completed in 0.0s
# [INFO][NORMALIZATION] Data Stats: {'mean': 6.40921274601687, 'std': 1.9843320697999307}
# [INFO][NORMALIZATION] min value: -2.222013549607867, max value: 2.7771497209833194
# [DEBUG][CHECK] Performing quick data checks on the first training sample.
# [DEBUG][CHECK] Complex ID: 1rnm
# [DEBUG][CHECK] Graph atoms: 269
# [DEBUG][CHECK] Feature dimension: 4
# [DEBUG][CHECK] Coordinates present (pos): True
# [INFO][DATA_QUALITY] Data quality registry active: bad_complexes.toml (2 entries)
# [INFO][EXPERIMENT] Dataset preparation finished in 4m 24.6s
# [INFO][EXPERIMENT] ============================================== *** STAGE: ENRICHMENT *** ===============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Preparing training datasets and loaders.
# [INFO][PROTEIN_CONTEXT] Preparing protein context embedding precompute: mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, batch_size=8, cache_path=protein_context_features
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'train' with 3201 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'train' completed in 3.1s (unique=2122, cached_before=2122, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'val' with 564 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'val' completed in 0.4s (unique=487, cached_before=487, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'test' with 289 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'test' completed in 0.2s (unique=219, cached_before=219, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Protein context embedding precompute completed in 46.4s (split_unique_total=2828, cached_before_total=2828, computed_now_total=0)
# [INFO][LIGAND_CONTEXT] Preparing ligand context embedding precompute: mode=basic_rdkit, descriptor_set=basic_physchem_v1, batch_size=256, cache_path=ligand_context_features
# [DEBUG][LIGAND_CONTEXT] Preparing ligand context precompute for split 'train' with 3201 ligands.
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t33_650M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t33_650M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D-contact-regression.pt
# Ligand context precompute (train):   0%|          | 0/11 [00:00<?, ?batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C(C([H])([H])C2:N:C3:C([H]):C([H]):C([H]):C(F):C:3:C3:N:2N=C(N([H])[H])N3[H]):C([H]):C2:C:1OC([H])([H])O2
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC([H])([H])C([H])([H])N([H])C1:C([H]):C(F):C([H]):C2:N:C(C([H])([H])C3:C([H]):C([H]):C4:C(:C:3[H])OC([H])([H])O4):N3:C(:C:1:2)N([H])C(N([H])[H])=N3
# Ligand context precompute (train):   9%|▉         | 1/11 [00:00<00:07,  1.39batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):N(C([H])([H])OC([H])([H])N2:C([H]):C([H]):C(C(=O)N([H])[H]):C([H]):C:2[H]):C([H]):C:1[H]
# Ligand context precompute (train):  18%|█▊        | 2/11 [00:01<00:06,  1.34batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC([H])([H])C([H])([H])N([H])C1:C([H]):C([H]):C2:C3:N(:C(C([H])([H])C4:C([H]):C([H]):C5:C(:C:4[H])OC([H])([H])O5):N:C:2:C:1[H])N=C(N([H])[H])N3[H]
# Ligand context precompute (train):  27%|██▋       | 3/11 [00:02<00:06,  1.21batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):N(C([H])([H])C([H])(P(=O)(=O)=O)P(=O)(=O)=O):C([H]):C:1OC([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C2:C3:C([H]):C(N([H])[H]):C([H]):C([H]):C:3:C3:C([H]):C([H]):C(N([H])[H]):C([H]):C:3:N:2C([H])([H])C([H])([H])C([H])([H])[N+](C([H])([H])[H])(C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])[H]):C([H]):C:1[H]
# Ligand context precompute (train):  45%|████▌     | 5/11 [00:04<00:05,  1.07batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]/C(C1=N(C([H])([H])[H])C2:C([H]):C([H]):C([H]):C([H]):C:2C1(C([H])([H])[H])C([H])([H])[H])=C(/[H])C([H])([H])C1:C([H]):C([H]):N(C([H])([H])C([H])([H])C([H])([H])S(=O)(=O)=O):C2:C([H]):C([H]):C([H]):C([H]):C:1:2
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C([H])([H])[C@]([H])(C(=O)N2C([H])([H])C([H])([H])C([H])([H])[C@@]2([H])C(=O)N([H])C([H])([H])C2:C([H]):C([H]):C([H]):N(C([H])([H])[H]):C:2[H])[N+]([H])([H])[H]):C([H]):C:1[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C(OC([H])([H])[H]):C([H]):C(C([H])([H])C2:N:C3:C([H]):C([H]):C([H]):C([H]):C:3:C3:N:2N=C(N([H])[H])N3[H]):C([H]):C:1OC([H])([H])[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]ON1:C(N([H])C([H])([H])C(F)(F)C2:C([H]):C([H]):C([H]):C([H]):N:2O[H]):C([H]):C([H]):C(Cl):C:1C([H])([H])C(=O)N([H])[C@@]([H])(C1:C([H]):C([H]):C([H]):C(Cl):C:1[H])C([H])([H])[H]
# Ligand context precompute (train):  55%|█████▍    | 6/11 [00:05<00:04,  1.13batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C([H])([H])[C@]([H])(C(=O)N2C([H])([H])C([H])([H])C([H])([H])[C@@]2([H])C(=O)N([H])C([H])([H])C2:C(Cl):C([H]):C([H]):N(C([H])([H])[H]):C:2[H])[N+]([H])([H])[H]):C([H]):C:1[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C2:C3:N(:C(C([H])([H])C([H])([H])C([H])([H])[H]):N:C:2:C:1[H])N=C(N([H])[H])N3[H]
# Ligand context precompute (train):  64%|██████▎   | 7/11 [00:05<00:03,  1.24batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C(C([H])([H])C2:N:C3:C([H]):C([H]):C([H]):C([H]):C:3:C3:N:2N=C(N([H])[H])N3[H]):C([H]):C2:C:1OC([H])([H])O2
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C2:C3:C([H]):C(N([H])[H]):C([H]):C([H]):C:3:C3:C([H]):C([H]):C(N([H])[H]):C([H]):C:3:N:2C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])c2nnn(C([H])([H])C([H])([H])N([H])C3:C4:C(:N:C5:C([H]):C([H]):C([H]):C([H]):C:3:5)C([H])([H])C([H])([H])C([H])([H])C4([H])[H])c2[H]):C([H]):C:1[H]
# Ligand context precompute (train):  73%|███████▎  | 8/11 [00:06<00:02,  1.31batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1=C2C([H])([H])C3:C4:C([H]):C5:C(:C([H]):C:4:C([H]):C([H]):N:3C([H])([H])[C@@]2([H])[C@]([H])(OC([H])([H])[H])C(OC([H])([H])[H])=C1[H])OC([H])([H])O5
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC1:C([H]):C(O[H]):C([H]):C(C([H])([H])C2:N:C3:C([H]):C([H]):C([H]):C([H]):C:3:C3:N:2N=C(N([H])[H])N3[H]):C:1[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC([H])([H])C([H])([H])[C@@]1([H])N(C2:N:C3:N(:C(N([H])C([H])([H])C4:C([H]):C([H]):C([H]):[N+]([O-]):C:4[H]):C:2[H])N([H])C([H])=C3C([H])([H])C([H])([H])[H])C([H])([H])C([H])([H])C([H])([H])C1([H])[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C(C([H])([H])[H]):C(C([H])([H])[H]):C([H]):C2:C:1:N:c1c(=O)n([H])c(=O)n([H])c1:N:2C([H])([H])[H]
# Ligand context precompute (train):  82%|████████▏ | 9/11 [00:07<00:01,  1.36batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C([H])([H])[C@]([H])(C(=O)N2C([H])([H])C([H])([H])C([H])([H])[C@@]2([H])C(=O)N([H])C([H])([H])C2:C([H]):C(Cl):C([H]):C([H]):N:2C([H])([H])[H])[N+]([H])([H])[H]):C([H]):C:1[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC(C([H])([H])N1:C([H]):C([H]):C([H]):C(C2:C([H]):C([H]):C([H]):C(C3:C([H]):C([H]):C([H]):C([H]):C:3[H]):C:2[H]):C:1[H])(P(=O)(=O)=O)P(=O)(=O)=O
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]OC([H])([H])[C@@]1([H])O[C@@]([H])(c2nn([H])c3:C(N([H])[H]):N(C([H])([H])[H]):C([H]):N:c23)[C@]([H])(O[H])[C@]1([H])O[H]
# Ligand context precompute (train): 100%|██████████| 11/11 [00:07<00:00,  1.38batch/s]
# [DEBUG][LIGAND_CONTEXT] Ligand context precompute for split 'train' completed in 9.8s (unique=2586, cached_before=0, computed_now=2586)
# [DEBUG][LIGAND_CONTEXT] Preparing ligand context precompute for split 'val' with 564 ligands.
# Ligand context precompute (val):   0%|          | 0/2 [00:00<?, ?batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C([H])([H])[C@]([H])(C(=O)N2C([H])([H])C([H])([H])C([H])([H])[C@@]2([H])C(=O)N([H])C([H])([H])C2:C([H]):C([H]):C([H]):C([H]):N:2C([H])([H])[H])[N+]([H])([H])[H]):C([H]):C:1[H]
# Ligand context precompute (val):  50%|█████     | 1/2 [00:00<00:00,  1.51batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C([H]):C(C([H])([H])[C@]([H])(C(=O)N2C([H])([H])C([H])([H])C([H])([H])[C@@]2([H])C(=O)N([H])C([H])([H])C2:C([H]):C([H]):N(C([H])([H])[H]):C([H]):C:2[H])[N+]([H])([H])[H]):C([H]):C:1[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C(C([H])([H])C2:N:C3:C([H]):C(S(=O)(=O)N([H])[H]):C([H]):C([H]):C:3:C3:N:2N=C(N([H])[H])N3[H]):C([H]):C2:C:1OC([H])([H])O2
# Ligand context precompute (val): 100%|██████████| 2/2 [00:00<00:00,  2.01batch/s]
# [DEBUG][LIGAND_CONTEXT] Ligand context precompute for split 'val' completed in 1.3s (unique=525, cached_before=147, computed_now=378)
# [DEBUG][LIGAND_CONTEXT] Preparing ligand context precompute for split 'test' with 289 ligands.
# Ligand context precompute (test):   0%|          | 0/1 [00:00<?, ?batch/s][WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:N:C([H]):C2:N(:C:1[H])C(N([H])C(C([H])([H])[H])(C([H])([H])[H])C([H])([H])[H])=C(C1:C([H]):C([H]):C(c3c(C([H])([H])[H])noc3C([H])([H])[H]):C([H]):C:1[H])N2[H]
# [WARNING][LIGAND_CONTEXT] Ligand context fallback to zero descriptor vector for unparsable SMILES: [H]C1:C([H]):C(C2:C([H]):C([H]):C(OC([H])([H])[H]):C([H]):C:2[H]):N2:C(:C:1[H])N([H])C(N([H])C1:C([H]):C([H]):C(N3C([H])([H])C([H])([H])[N+]([H])(C([H])([H])[H])C([H])([H])C3([H])[H]):C([H]):C:1[H])=N2
# Ligand context precompute (test): 100%|██████████| 1/1 [00:00<00:00,  1.81batch/s]
# [DEBUG][LIGAND_CONTEXT] Ligand context precompute for split 'test' completed in 0.7s (unique=289, cached_before=52, computed_now=237)
# [DEBUG][LIGAND_CONTEXT] Ligand context embedding precompute completed in 13.2s (split_unique_total=3400, cached_before_total=199, computed_now_total=3201)
# [INFO][PROTEIN_CONTEXT] Preparing protein context prewarm: mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, repr_layer=33, pooling=mean, cache_path=protein_context_features
# [DEBUG][PROTEIN_CONTEXT] Protein context encoder weights are warmed up in 13.5s.
# [INFO][PROTEIN_CONTEXT] Protein context settings -> mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, repr_layer=33, pooling=mean, cache_path=protein_context_features, max_length=1022
# [INFO][LIGAND_CONTEXT] Ligand context settings -> mode=basic_rdkit, descriptor_set=basic_physchem_v1, cache_path=ligand_context_features, embedding_dim=7
# [INFO][EXPERIMENT] ============================================= *** STAGE: RUN SETTINGS *** ==============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Run settings -> source_subset=refined, core_as_test=True, splitter=random, batch_size=2, num_workers=0, splitter_seed=42, model=A3, epochs=100
# [INFO][MODEL] Global graph settings -> mode=interaction, dist_threshold=5.0, ca_only=False
# [INFO][MODEL] Global encoder settings -> hidden_channels=128, cutoff=5.0, max_num_neighbors=12, num_blocks=3, protein_context=esm_frozen_whole, ligand_context=basic_rdkit
# [INFO][MODEL] Local branch settings -> local_graph=radius (dist_threshold=3.5), local_encoder=DimeNet, hidden_channels=128, cutoff=3.5, max_num_neighbors=12, num_blocks=3
# [INFO][OPTIMIZER] Optimizer settings -> type=AdamW, lr=0.0001, weight_decay=0.01
# [INFO][MODEL] Preparing model initialization.
# [DEBUG][MODEL] Model initialization completed in 40.0s
# [INFO][EXPERIMENT] Launch on: cuda
# [INFO][OPTIMIZER] Parameter summary: total=653.03M | trainable=1.99M | frozen=651.04M | groups=7
# [INFO][OPTIMIZER] Optimizer split -> classic=653.03M params in 785 tensors (100.0%) | quantum=0 params in 0 tensors (0.0%)
# [INFO][OPTIMIZER] gnn                          | split=classic | status=trainable | params= 895.37K (trainable=895.37K, frozen=0)
# [INFO][OPTIMIZER] head                         | split=classic | status=trainable | params=  33.03K (trainable=33.03K, frozen=0)
# [INFO][OPTIMIZER] ligand_context_projector     | split=classic | status=trainable | params=   1.04K (trainable=1.04K, frozen=0)
# [INFO][OPTIMIZER] local_gnn                    | split=classic | status=trainable | params= 895.37K (trainable=895.37K, frozen=0)
# [INFO][OPTIMIZER] local_output_norm            | split=classic | status=trainable | params=     256 (trainable=256, frozen=0)
# [INFO][OPTIMIZER] protein_context_encoder      | split=classic | status=frozen    | params= 651.04M (trainable=0, frozen=651.04M)
# [INFO][OPTIMIZER] protein_context_projector    | split=classic | status=trainable | params= 166.53K (trainable=166.53K, frozen=0)
# [DEBUG][OPTIMIZER] gnn                          | split=classic | status=trainable | tensors=114 (trainable=114, frozen=0) | params= 895.37K | trainable= 895.37K (100.0%) | frozen=       0 (0.0%) | classic= 895.37K | quantum=       0
# [DEBUG][OPTIMIZER] head                         | split=classic | status=trainable | tensors=  9 (trainable=9, frozen=0) | params=  33.03K | trainable=  33.03K (100.0%) | frozen=       0 (0.0%) | classic=  33.03K | quantum=       0
# [DEBUG][OPTIMIZER] ligand_context_projector     | split=classic | status=trainable | tensors=  4 (trainable=4, frozen=0) | params=   1.04K | trainable=   1.04K (100.0%) | frozen=       0 (0.0%) | classic=   1.04K | quantum=       0
# [DEBUG][OPTIMIZER] local_gnn                    | split=classic | status=trainable | tensors=114 (trainable=114, frozen=0) | params= 895.37K | trainable= 895.37K (100.0%) | frozen=       0 (0.0%) | classic= 895.37K | quantum=       0
# [DEBUG][OPTIMIZER] local_output_norm            | split=classic | status=trainable | tensors=  2 (trainable=2, frozen=0) | params=     256 | trainable=     256 (100.0%) | frozen=       0 (0.0%) | classic=     256 | quantum=       0
# [DEBUG][OPTIMIZER] protein_context_encoder      | split=classic | status=frozen    | tensors=538 (trainable=0, frozen=538) | params= 651.04M | trainable=       0 (0.0%) | frozen= 651.04M (100.0%) | classic= 651.04M | quantum=       0
# [DEBUG][OPTIMIZER] protein_context_projector    | split=classic | status=trainable | tensors=  4 (trainable=4, frozen=0) | params= 166.53K | trainable= 166.53K (100.0%) | frozen=       0 (0.0%) | classic= 166.53K | quantum=       0
# [WARNING][OPTIMIZER] Quantum: No quantum parameters found, optimizer disabled
# [INFO][LossFunction] Using built-in PyTorch loss HuberLoss
# [INFO][LossFunction] Slope regularization: False
# [INFO][METRICS] Primary metric: val_pearson with mode max
# [INFO][METRICS] Early stopping enabled with patience 10
# [INFO][METRICS] Monitors: {'val_pearson': 'max', 'val_rmse': 'min', 'train_loss': 'ignore', 'val_ci': 'max'}
# [INFO][EXPERIMENT] =============================================== *** STAGE: TRAINING *** ================================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][TRAINER] [EPOCH 1/100] progress=0.000 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_1_start | rss=7.5GB | rss_peak=7.5GB | sys_avail=3.8GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=2.6GB | cuda_max_alloc=2.5GB | cuda_max_reserved=2.6GB
# [INFO][TRAINER] [EPOCH 1/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.5GB | rss_peak=7.5GB | sys_avail=3.8GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=2.6GB | cuda_max_alloc=2.5GB | cuda_max_reserved=2.6GB
# Training: 100%|██████████| 1601/1601 [04:04<00:00,  6.56batch/s, Loss: 0.0015 [          ] Avg: 0.3603]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.6GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.6GB
# [DEBUG][MEMORY] epoch_1_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.6GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.6GB
# [DEBUG][TRAINER] [EPOCH 1/100] Training pass completed in 4m 4.2s
# [INFO][TRAINER] [EPOCH 1/100] Validation.
# [DEBUG][MEMORY] epoch_1_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.6GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.6GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.6GB
# [DEBUG][TRAINER] [EPOCH 1/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 1/100] Train Loss: 0.3603, Val Loss: 0.3338
# [DEBUG][TRAINER] [EPOCH 1/100] Train_time=4m 4.2s | Val_time=25.8s | Train_eval_time=2m 20.8s | epoch_time=4m 30.0s
# [DEBUG][TRAINER] [EPOCH 1/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 1/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 1/100] Train(eval): RMSE 1.6767 | R 0.5946 | CI 0.7131
# [INFO][TRAINER] [EPOCH 1/100] Valid: RMSE 1.7140 | R 0.5917 | CI 0.7099
# [DEBUG][TRAINER] [EPOCH 1/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.5917
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.7140
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7099
# [DEBUG][TRAINER] [EPOCH 1/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 1/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 1/100] Best model checkpoint saved in 0.0s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.5917 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 1/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 1/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 1/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 1/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 1/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 2/100] progress=0.010 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_2_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.8GB
# [INFO][TRAINER] [EPOCH 2/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=2.5GB | cuda_max_reserved=5.8GB
# Training: 100%|██████████| 1601/1601 [03:55<00:00,  6.79batch/s, Loss: 0.1711 [          ] Avg: 0.3083]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][MEMORY] epoch_2_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 2/100] Training pass completed in 3m 55.8s
# [INFO][TRAINER] [EPOCH 2/100] Validation.
# [DEBUG][MEMORY] epoch_2_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 2/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 2/100] Train Loss: 0.3083, Val Loss: 0.3125
# [DEBUG][TRAINER] [EPOCH 2/100] Train_time=3m 55.8s | Val_time=24.5s | Train_eval_time=2m 19.7s | epoch_time=4m 20.4s
# [DEBUG][TRAINER] [EPOCH 2/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 2/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 2/100] Train(eval): RMSE 1.6015 | R 0.6589 | CI 0.7395
# [INFO][TRAINER] [EPOCH 2/100] Valid: RMSE 1.6538 | R 0.6502 | CI 0.7350
# [DEBUG][TRAINER] [EPOCH 2/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.6502
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.6538
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7350
# [DEBUG][TRAINER] [EPOCH 2/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 2/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 2/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.6502 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 2/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 2/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 2/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 2/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 2/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 3/100] progress=0.020 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_3_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [INFO][TRAINER] [EPOCH 3/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=2.5GB | cuda_max_reserved=5.8GB
# Training: 100%|██████████| 1601/1601 [04:03<00:00,  6.56batch/s, Loss: 0.5296 [██        ] Avg: 0.2848]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][MEMORY] epoch_3_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 3/100] Training pass completed in 4m 4.0s
# [INFO][TRAINER] [EPOCH 3/100] Validation.
# [DEBUG][MEMORY] epoch_3_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 3/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 3/100] Train Loss: 0.2848, Val Loss: 0.2717
# [DEBUG][TRAINER] [EPOCH 3/100] Train_time=4m 4.0s | Val_time=25.1s | Train_eval_time=2m 23.6s | epoch_time=4m 29.1s
# [DEBUG][TRAINER] [EPOCH 3/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 3/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 3/100] Train(eval): RMSE 1.4881 | R 0.6636 | CI 0.7417
# [INFO][TRAINER] [EPOCH 3/100] Valid: RMSE 1.5347 | R 0.6627 | CI 0.7432
# [DEBUG][TRAINER] [EPOCH 3/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.6627
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.5347
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7432
# [DEBUG][TRAINER] [EPOCH 3/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 3/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 3/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.6627 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 3/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 3/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 3/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 3/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 3/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 4/100] progress=0.030 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_4_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [INFO][TRAINER] [EPOCH 4/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=2.5GB | cuda_max_reserved=5.8GB
# Training: 100%|██████████| 1601/1601 [04:03<00:00,  6.58batch/s, Loss: 0.3333 [█         ] Avg: 0.2679]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.8GB
# [DEBUG][MEMORY] epoch_4_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 4/100] Training pass completed in 4m 3.5s
# [INFO][TRAINER] [EPOCH 4/100] Validation.
# [DEBUG][MEMORY] epoch_4_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 4/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 4/100] Train Loss: 0.2679, Val Loss: 0.2784
# [DEBUG][TRAINER] [EPOCH 4/100] Train_time=4m 3.5s | Val_time=25.3s | Train_eval_time=2m 23.3s | epoch_time=4m 28.8s
# [DEBUG][TRAINER] [EPOCH 4/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 4/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 4/100] Train(eval): RMSE 1.4758 | R 0.6805 | CI 0.7485
# [INFO][TRAINER] [EPOCH 4/100] Valid: RMSE 1.5423 | R 0.6680 | CI 0.7443
# [DEBUG][TRAINER] [EPOCH 4/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.6680
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7443
# [DEBUG][TRAINER] [EPOCH 4/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 4/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 4/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.6680 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 4/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 4/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 4/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 4/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 4/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 5/100] progress=0.040 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_5_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.1GB | cuda_max_reserved=5.8GB
# [INFO][TRAINER] [EPOCH 5/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=2.5GB | cuda_max_reserved=5.8GB
# Training: 100%|██████████| 1601/1601 [04:00<00:00,  6.66batch/s, Loss: 1.1209 [███       ] Avg: 0.2547]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][MEMORY] epoch_5_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 5/100] Training pass completed in 4m 0.4s
# [INFO][TRAINER] [EPOCH 5/100] Validation.
# [DEBUG][MEMORY] epoch_5_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [DEBUG][TRAINER] [EPOCH 5/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 5/100] Train Loss: 0.2547, Val Loss: 0.2854
# [DEBUG][TRAINER] [EPOCH 5/100] Train_time=4m 0.4s | Val_time=25.0s | Train_eval_time=2m 21.9s | epoch_time=4m 25.4s
# [DEBUG][TRAINER] [EPOCH 5/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 5/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 5/100] Train(eval): RMSE 1.4970 | R 0.7135 | CI 0.7650
# [INFO][TRAINER] [EPOCH 5/100] Valid: RMSE 1.5728 | R 0.6999 | CI 0.7564
# [DEBUG][TRAINER] [EPOCH 5/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.6999
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7564
# [DEBUG][TRAINER] [EPOCH 5/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 5/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 5/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.6999 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 5/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 5/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 5/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 5/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 5/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 6/100] progress=0.051 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_6_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=4.0GB | cuda_max_reserved=5.8GB
# [INFO][TRAINER] [EPOCH 6/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=5.8GB | cuda_max_alloc=2.5GB | cuda_max_reserved=5.8GB
# Training: 100%|██████████| 1601/1601 [04:02<00:00,  6.60batch/s, Loss: 0.7367 [██        ] Avg: 0.2422]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.2GB | cuda_max_reserved=6.1GB
# [DEBUG][MEMORY] epoch_6_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.2GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 6/100] Training pass completed in 4m 2.6s
# [INFO][TRAINER] [EPOCH 6/100] Validation.
# [DEBUG][MEMORY] epoch_6_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.2GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 6/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 6/100] Train Loss: 0.2422, Val Loss: 0.2586
# [DEBUG][TRAINER] [EPOCH 6/100] Train_time=4m 2.6s | Val_time=25.5s | Train_eval_time=2m 22.5s | epoch_time=4m 28.1s
# [DEBUG][TRAINER] [EPOCH 6/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 6/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 6/100] Train(eval): RMSE 1.3634 | R 0.7414 | CI 0.7771
# [INFO][TRAINER] [EPOCH 6/100] Valid: RMSE 1.4882 | R 0.7049 | CI 0.7577
# [DEBUG][TRAINER] [EPOCH 6/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.7049
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.4882
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7577
# [DEBUG][TRAINER] [EPOCH 6/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 6/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 6/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.7049 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 6/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 6/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 6/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 6/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 6/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 7/100] progress=0.061 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_7_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.2GB | cuda_max_reserved=6.1GB
# [INFO][TRAINER] [EPOCH 7/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=2.5GB | cuda_max_reserved=6.1GB
# Training: 100%|██████████| 1601/1601 [04:03<00:00,  6.58batch/s, Loss: 0.8203 [███       ] Avg: 0.2303]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][MEMORY] epoch_7_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 7/100] Training pass completed in 4m 3.2s
# [INFO][TRAINER] [EPOCH 7/100] Validation.
# [DEBUG][MEMORY] epoch_7_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 7/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 7/100] Train Loss: 0.2303, Val Loss: 0.2512
# [DEBUG][TRAINER] [EPOCH 7/100] Train_time=4m 3.2s | Val_time=24.9s | Train_eval_time=2m 21.5s | epoch_time=4m 28.1s
# [DEBUG][TRAINER] [EPOCH 7/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 7/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 7/100] Train(eval): RMSE 1.3571 | R 0.7299 | CI 0.7720
# [INFO][TRAINER] [EPOCH 7/100] Valid: RMSE 1.4738 | R 0.6959 | CI 0.7551
# [DEBUG][TRAINER] [EPOCH 7/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.4738
# [DEBUG][TRAINER] [EPOCH 7/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 7/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 7/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 7/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 7/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 7/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 8/100] progress=0.071 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_8_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [INFO][TRAINER] [EPOCH 8/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=2.5GB | cuda_max_reserved=6.1GB
# Training: 100%|██████████| 1601/1601 [04:02<00:00,  6.60batch/s, Loss: 0.0677 [          ] Avg: 0.2260]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][MEMORY] epoch_8_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 8/100] Training pass completed in 4m 2.8s
# [INFO][TRAINER] [EPOCH 8/100] Validation.
# [DEBUG][MEMORY] epoch_8_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 8/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 8/100] Train Loss: 0.2260, Val Loss: 0.2523
# [DEBUG][TRAINER] [EPOCH 8/100] Train_time=4m 2.8s | Val_time=25.1s | Train_eval_time=2m 22.7s | epoch_time=4m 27.9s
# [DEBUG][TRAINER] [EPOCH 8/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 8/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 8/100] Train(eval): RMSE 1.3082 | R 0.7628 | CI 0.7870
# [INFO][TRAINER] [EPOCH 8/100] Valid: RMSE 1.4727 | R 0.7095 | CI 0.7577
# [DEBUG][TRAINER] [EPOCH 8/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.7095
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.4727
# [DEBUG][TRAINER] [EPOCH 8/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 8/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 8/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.7095 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 8/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 8/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 8/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 8/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 8/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 9/100] progress=0.081 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_9_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.0GB | cuda_max_reserved=6.1GB
# [INFO][TRAINER] [EPOCH 9/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=2.5GB | cuda_max_reserved=6.1GB
# Training: 100%|██████████| 1601/1601 [04:02<00:00,  6.60batch/s, Loss: 0.1140 [          ] Avg: 0.2160]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][MEMORY] epoch_9_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 9/100] Training pass completed in 4m 2.5s
# [INFO][TRAINER] [EPOCH 9/100] Validation.
# [DEBUG][MEMORY] epoch_9_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 9/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 9/100] Train Loss: 0.2160, Val Loss: 0.2520
# [DEBUG][TRAINER] [EPOCH 9/100] Train_time=4m 2.5s | Val_time=25.5s | Train_eval_time=2m 23.0s | epoch_time=4m 28.0s
# [DEBUG][TRAINER] [EPOCH 9/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 9/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 9/100] Train(eval): RMSE 1.3105 | R 0.7676 | CI 0.7910
# [INFO][TRAINER] [EPOCH 9/100] Valid: RMSE 1.4791 | R 0.7098 | CI 0.7605
# [DEBUG][TRAINER] [EPOCH 9/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.7098
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7605
# [DEBUG][TRAINER] [EPOCH 9/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 9/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 9/100] Best model checkpoint saved in 0.0s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.7098 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 9/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 9/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 9/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 9/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 9/100] Schedulers updated in 0.0s
# [INFO][TRAINER] ------------------------------------------------------------------------------------------------------------------------
# [INFO][TRAINER] [EPOCH 10/100] progress=0.091 classic_lr=[0.0001] quantum_lr=None
# [DEBUG][MEMORY] epoch_10_start | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [INFO][TRAINER] [EPOCH 10/100] Preparing training epoch.
# [DEBUG][MEMORY] train_epoch_start | batch=0/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=2.5GB | cuda_max_reserved=6.1GB
# Training: 100%|██████████| 1601/1601 [04:03<00:00,  6.58batch/s, Loss: 0.4096 [██        ] Avg: 0.2053]
# [DEBUG][MEMORY] train_epoch_end | batch=1601/1601 | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][MEMORY] epoch_10_after_train | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 10/100] Training pass completed in 4m 3.2s
# [INFO][TRAINER] [EPOCH 10/100] Validation.
# [DEBUG][MEMORY] epoch_10_after_val | rss=7.7GB | rss_peak=7.7GB | sys_avail=3.7GB | sys_total=12.7GB | cuda_alloc=2.5GB | cuda_reserved=6.1GB | cuda_max_alloc=4.1GB | cuda_max_reserved=6.1GB
# [DEBUG][TRAINER] [EPOCH 10/100] Preparing train-set evaluation metrics.
# [INFO][TRAINER] [EPOCH 10/100] Train Loss: 0.2053, Val Loss: 0.2333
# [DEBUG][TRAINER] [EPOCH 10/100] Train_time=4m 3.2s | Val_time=24.6s | Train_eval_time=2m 21.3s | epoch_time=4m 27.9s
# [DEBUG][TRAINER] [EPOCH 10/100] Preparing denormalized validation metrics.
# [DEBUG][TRAINER] [EPOCH 10/100] Denormalized validation metrics prepared in 0.0s
# [INFO][TRAINER] [EPOCH 10/100] Train(eval): RMSE 1.1965 | R 0.8011 | CI 0.8080
# [INFO][TRAINER] [EPOCH 10/100] Valid: RMSE 1.4135 | R 0.7319 | CI 0.7704
# [DEBUG][TRAINER] [EPOCH 10/100] Checking monitored metrics for improvements.
# [INFO][TRAINER] Improved: Primary metric 'val_pearson': 0.7319
# [INFO][TRAINER] Improved: Secondary metric 'val_rmse': 1.4135
# [INFO][TRAINER] Improved: Secondary metric 'val_ci': 0.7704
# [DEBUG][TRAINER] [EPOCH 10/100] Metric improvement check completed in 0.0s
# [DEBUG][TRAINER] [EPOCH 10/100] Saving best model.
# [DEBUG][TRAINER] [EPOCH 10/100] Best model checkpoint saved in 0.1s
# [DEBUG][TRAINER] New best for primary metric val_pearson: 0.7319 (Saved to best_model.pt)
# [DEBUG][TRAINER] [EPOCH 10/100] Updating early stopping state.
# [DEBUG][TRAINER] [EPOCH 10/100] Saving history.json.
# [DEBUG][TRAINER] [EPOCH 10/100] history.json saved in 0.0s
# [DEBUG][TRAINER] [EPOCH 10/100] Updating schedulers.
# [DEBUG][TRAINER] [EPOCH 10/100] Schedulers updated in 0.0s
# [DEBUG][TRAINER] [EPOCH 10/100] Rendering ASCII dashboard.
# [INFO][TRAINER] Generating Multi-column ASCII Dashboard.
# [INFO][TRAINER]
# Learning Curve (Loss)                                           Validation RMSE
# ▘=Train Loss  *=Val Loss                                        ▘=Train RMSE  *=Val RMSE
# +------------------------------------------------+              +------------------------------------------------+
# |▘                                               | 0.3603       |*                                               | 1.7140
# |                                                |              |▘    *                                          |
# ...
# +------------------------------------------------------------------------------+
# 1                                                                           40
# [INFO][SUMMARY] Pearson (R) Curve:
# Correlation (Pearson R)
# ▘=Train Pearson  *=Val Pearson
# +------------------------------------------------------------------------------+
# |                                                               ▘ ▘ ▘ ▘ ▘ ▘ ▘ ▘| 0.9873
# |                                                 ▘ ▘ ▘ ▘ ▘ ▘ ▘                |
# |                                           ▘ ▘ ▘                              |
# |                                         ▘                                    |
# |                                    ▘ ▘▘                                      |
# |                                ▘ ▘                                           |
# |                              ▘                                               | 0.8794
# |                            ▘                                                 |
# |                          ▘                                                   |
# |                        ▘                                                     |
# |                  ▘ ▘ ▘                                                       |
# |                                                                              | 0.7895
# |              ▘ ▘                                                             |
# |                                *      *                                      |
# |          ▘ ▘     *         * *   * * *  * * * * * * * * * * * * * * * * * * *|
# |        ▘     * *   * * * *                                                   |
# |        * * *                                                                 | 0.6996
# |      ▘                                                                       |
# |  ▘ ▘ *                                                                       |
# |  *                                                                           |
# |                                                                              |
# |                                                                              |
# |▘                                                                             | 0.5917
# +------------------------------------------------------------------------------+
# 1                                                                           40
# [INFO][SUMMARY] Concordancy Index Curve:
# Ranking Accuracy (CI)
# ▘=Train CI  *=Val CI
# +------------------------------------------------------------------------------+
# |                                                                       ▘ ▘ ▘ ▘| 0.9720
# |                                                               ▘ ▘ ▘ ▘        |
# |                                                             ▘                |
# |                                                   ▘ ▘ ▘ ▘ ▘                  |
# |                                             ▘ ▘ ▘                            |
# |                                           ▘                                  |
# |                                         ▘                                    | 0.9005
# |                                      ▘▘                                      |
# |                                  ▘ ▘                                         |
# |                                ▘                                             |
# |                              ▘                                               |
# |                            ▘                                                 | 0.8409
# |                          ▘                                                   |
# |                    ▘ ▘ ▘                                                     |
# |                  ▘                                                           |
# |                ▘                                                             |
# |          ▘   ▘               * *      *       *   * *   *   * *     *        | 0.7814
# |        ▘   ▘     * * *   * *     * * *  * * *   *     *   *     * *   * * * *|
# |        * * * * *       *                                                     |
# |    ▘ ▘                                                                       |
# |  ▘                                                                           |
# |                                                                              |
# |▘                                                                             | 0.7099
# +------------------------------------------------------------------------------+
# 1                                                                           40
# [INFO][SUMMARY] Actual vs Predicted Scatter Plot:
#                               Predicted = f(Actual)
# ┌────────────────────────────────────────────────────────────────────────────────┐
# │                                                                             ▗▄▀│
# │                                                ▗                         ▄▞▀▘  │
# │                                                                       ▄▞▀      │
# │                                             ▖           ▘  ▝      ▗▄▀▀▗     ▗▝▗│
# │                                                   ▘ ▝▝  ▖▝   ▝ ▗▄▀▘          ▝ │ 10
# │                      ▘  ▝                  ▝         ▘▝▗    ▄▞▀▘        ▘      │
# │                                        ▘   ▘▘▗▝    ▜▝ ▖▄ ▄▞▀ ▖▛ ▝    ▗         │
# │              ▗          ▗    ▖    ▖▝   ▌▐▙▝▐▖▀▐ ▚  ▝▘▗▄▀▀  ▘▄▖            ▗    │
# │             ▝    ▗          ▗  ▝▝ ▖ ▗ ▝▝ ▟▖  ▖▘ ▘ ▗▄▀▘▝▗ ▖▐▝          ▘ ▗      │
# │     ▗              ▗    ▗   ▞  ▗   ▖▐▞▖   ▌ ▌▝▞▄▞▀▘▝ ▘ ▝ ▄   ▘      ▗ ▝        │
# │                       ▖  ▘▗  ▘▙ ▐▜▚▐ ▘▌ ▟▖ ▖▄▞▀▖ ▝▗▝▀▖     ▗▘  ▖    ▗          │
# │                ▘  ▝ ▖ ▗▌     ▝ ▘ ▝ ▟▐▖▝▀▗▄▀▀▗▌ ▌▖ ▜▞   ▗                       │
# │       ▖   ▖      ▘   ▝▜ ▖▘ ▝▗▝▝▗ ▝▚▚ ▗▄▀▘▝▗ ▝▖▘     ▝▖                 ▗       │
# │            ▖ ▞     ▐ ▗▐ ▄▀  █ ▐▖▐ ▄▄▀▘▝ ▙▖▌ ▞   ▘      ▘                       │
# │        ▘▗  ▖ ▝ ▖ ▝▗▘▚▖ ▀▖▝▗▄   ▄▞▀▌▘ ▗▛▗ ▝ ▜▝ ▝         ▝       ▖              │
# │▖       ▗  ▞ ▀▖ ▗▖  ▘▗▝ ▘▘▐▗▗▄▞▀ ▀▝ ▝     ▀▖    ▖                               │
# │      ▝   ▗  ▘▖  ▘▗▗▄█  ▐▗▄▀▘ ▗▐▖   ▟▝ ▖ ▜        ▗ ▗                           │
# │▗ ▗   ▖▄▗▝  ▌▐▝▞▘  ▖▌▞▄▄▀▘▖ ▘▘▀▖▀▝   ▐     ▝▗▘                                  │ 5
# │ ▖▘ ▗▘▗▀ ▝ ▚▝  ▌▝▖ ▄▞▀ ▝▀▘  ▝  ▗          ▘   ▝                                 │
# │▖     ▗ ▘▚▙▄▗  ▗▄▞▀ ▟▖       ▖▗▖ ▗▖  ▝  ▗                                       │
# │ ▗ ▝▖ ▝▖▘▞▚▚▗▄▀▘▖        ▖  ▝▝ ▗         ▖                                      │
# │ ▄▗     ▘▄▄▀▘   ▗     ▝             ▘                                           │
# │▖▘▗   ▄▞▀                                                                       │
# │ ▖▗▄▞▀ ▘                                                                        │
# │▄▀▘       ▘                                                                     │
# └────────────────────────────────────────────────────────────────────────────────┘
#        3        4       5       6        7       8       9      10       11
# [INFO][SUMMARY] Errors Distribution (Residuals):
#                               Residuals Distribution
# ┌────────────────────────────────────────────────────────────────────────────────┐
# │                                 ▐▖                                             │
# │                                 ▌▝▚                                            │
# │                                ▐ │ ▚                                           │ 80
# │                                ▞ │  ▜▄                                         │
# │                               ▗▘ │    ▀▄▖                                      │
# │                               ▐  │      ▝▀▄▄▖                                  │
# │                               ▌  │          ▝▚                                 │
# │                              ▐   │            ▌                                │
# │                              ▞   │            ▝▖                               │ 60
# │                             ▗▘   │             ▚                               │
# │                             ▐    │              ▌                              │
# │                           ▗▞▘    │              ▝▖                             │
# │                          ▄▘      │               ▚                             │
# │                         ▛        │                ▚                            │ 40
# │                        ▞         │                 ▌                           │
# │                       ▞          │                 ▝▖                          │
# │                      ▗▘          │                  ▝▖                         │
# │                     ▗▘           │                   ▚▖                        │
# │                    ▗▌            │                    ▝▚▖                      │
# │                   ▗▘             │                      ▝▚                     │ 20
# │                  ▞▘              │                        ▚▖                   │
# │            ▄▄▄▄▄▞                │                         ▝▖                  │
# │         ▄▞▀                      │                          ▝▖                 │
# │      ▄▞▀                         │                           ▝▀▄▄▄▖            │
# │▀▀▀▀▀▀                            │                                ▝▀▀▄▄▄▄▞▀▀▀▀▀│
# └────────────────────────────────────────────────────────────────────────────────┘
#        -3       -2       -1        0        1        2        3        4        5
# [INFO][SUMMARY] Generating Multi-column ASCII Dashboard.
# [INFO][SUMMARY]
# Learning Curve (Loss)                                           Validation RMSE
# ▘=Train Loss  *=Val Loss                                        ▘=Train RMSE  *=Val RMSE
# +------------------------------------------------+              +------------------------------------------------+
# |▘                                               | 0.3603       |▘                                               | 1.7140
# |*                                               |              | ▘  **                                          |
# | ▘                                              |              |  ▘ ▘▘*** * *** ** *  ****          *         **|
# |  ▘ ▘*                                          | 0.2735       |      ▘▘▘ ▘*      * *      ***** *** * ***** *  | 1.3645
# |     ▘▘▘* ***** ****  ****    *   * *      *  **|              |           ▘▘▘▘                                 |
# |        ▘ ▘▘        *      *** * * * * ****  *  |              |                ▘▘                              |
# |            ▘▘▘                                 | 0.1866       |                  ▘                             | 1.0149
# |                ▘                               |              |                   ▘▘ ▘ ▘                       |
# |                 ▘▘▘                            |              |                       ▘ ▘                      |
# |                    ▘ ▘▘                        | 0.0998       |                           ▘▘                   | 0.6654
# |                        ▘▘ ▘                    |              |                             ▘▘▘ ▘▘ ▘           |
# |                            ▘▘▘▘ ▘▘▘▘▘          |              |                                   ▘ ▘ ▘▘▘      |
# |                                       ▘▘▘▘▘ ▘▘▘| 0.0130       |                                          ▘▘ ▘▘▘| 0.3158
# +------------------------------------------------+              +------------------------------------------------+
# 1                                             40                1                                             40
# [INFO][SUMMARY]
# Correlation (Pearson R)                                         Ranking Accuracy (CI)
# ▘=Train Pearson  *=Val Pearson                                  ▘=Train CI  *=Val CI
# +------------------------------------------------+              +------------------------------------------------+
# |                                     ▘ ▘▘▘▘▘ ▘▘▘| 0.9873       |                                          ▘▘ ▘▘▘| 0.9720
# |                           ▘▘▘▘▘ ▘▘▘▘           |              |                                  ▘▘▘▘ ▘▘▘      |
# |                    ▘ ▘▘▘▘                      |              |                            ▘▘▘▘ ▘              |
# |                  ▘▘                            | 0.8884       |                         ▘ ▘                    | 0.9065
# |                ▘▘                              |              |                    ▘ ▘▘▘                       |
# |             ▘▘                                 |              |                  ▘▘                            |
# |           ▘▘                                   | 0.7895       |                ▘▘                              | 0.8409
# |      ▘ ▘ ▘       **  * *  *   * * *            |              |            ▘▘▘                                 |
# |     ▘ ▘* ***** **  *  * *  ***   * ** ***** ***|              |        ▘ ▘▘                                    |
# |    ▘***                                        | 0.6906       |     ▘▘▘   ***  ***** **** ***** ***** ***** ***| 0.7754
# | ▘▘ *                                           |              |  * ▘**** *   *                                 |
# |                                                |              | ▘▘                                             |
# |▘                                               | 0.5917       |▘                                               | 0.7099
# +------------------------------------------------+              +------------------------------------------------+
# 1                                             40                1                                             40
# [INFO][SUMMARY] Final Performance Analytics:
#                 Actual vs Predicted                                            Residuals Distribution
# ┌──────────────────────────────────────────────────┐            ┌──────────────────────────────────────────────────┐
# │                                               ▄▄▀│            │                    ▗▚                            │
# │                              ▘      ▗      ▄▞▀   │            │                    ▞│▚▖                          │
# │                            ▘  ▗ ▗▖▝▗  ▘▗▄▀▀▝   ▝▛│ 10         │                    ▌│ ▝▚▖                        │ 75
# │             ▝  ▘        ▖ ▐▖▗  ▗▞▝▝ ▄▞▀▘    ▝    │            │                   ▐ │   ▝▀▀▄                     │
# │         ▖      ▖ ▗ ▖▖▖▖▗▌▙▜▞█▐▖▝▗▄▀▀▄▟▘    ▌  ▖  │            │                   ▌ │       ▚                    │
# │   ▗    ▝  ▝ ▖  ▖ ▟ ▖ ▚▐▄▘▜▖▞▜▄▄▀▘▝▞▙▘▗    ▗▗ ▘   │            │                  ▗▘ │        ▌                   │
# │          ▖ ▖ ▐▖▘▘▝▟▖▜▟▛█▟▗▄▞▀▙▝█▚ ▖ ▝▘ ▘  ▖      │            │                 ▗▞  │        ▝▖                  │ 50
# │    ▗ ▗    ▘ ▘▜▚▚ ▙▀▗▞▞▗▄▀▘▌▜▀▚ ▘▚ ▖         ▖    │            │               ▗▄▘   │         ▜                  │
# │     ▖▖▐ ▘▖▝▟▚▀▜▜▄▘▝▄▞▀▘█▐▀▜▚▗      ▘   ▗         │            │               ▞     │          ▚                 │
# │▘   ▖▝▗▘█▘▜▗▐▟▘▙▗▄▀▀▝▀▝▄ ▗▛▘  ▘▗                  │            │              ▞      │           ▚                │
# │▗▐ ▄▗▞▌▟▟▜▌ █▄▄▀▘▐▀▛▘▘▝▐▝ ▌▚▘▖  ▝                 │ 5          │             ▗▘      │           ▝▙               │ 25
# │▞ ▖▘▌▞▄▌▖▗▄▞▀▌ ▝  ▄▟ ▖ ▝ ▗                        │            │            ▄▘       │             ▀▄             │
# │ ▖▝ ▀▛▄▄▀▘▘   ▖▝  ▘▝  ▗  ▝                        │            │        ▄▄▄▞         │               ▚            │
# │▞▝ ▄▞▀    ▘                                       │            │    ▗▄▞▀             │                ▀▄          │
# │▄▀▀   ▖                                           │            │▄▄▄▀▘                │                  ▀▀▀▚▄▄▄▄▀▀│
# └──────────────────────────────────────────────────┘            └──────────────────────────────────────────────────┘
#           4         6          8        10                                -2          0          2           4
# [INFO][EXPERIMENT] Experiment completed successfully in 4h 29m 46.9s.

# %% [markdown]
# ### 11. Inspect local outputs after the run
# <small>
# Эта ячейка нужна, чтобы быстро посмотреть:
#
# - жив ли `esm_cache/`,
# - сколько там файлов,
# - какие папки появились в `runs/`.
#
# Это просто быстрая sanity-check стадия перед финальным sync обратно на **Drive**.
# </small>

# %%
# !du -sh /content/DUMPLINGs/protein_context_features 2>/dev/null || echo "protein_context_features is absent"
# !find /content/DUMPLINGs/protein_context_features -type f | wc -l
# !ls -lt /content/DUMPLINGs/runs | head
# Out:
# 21M	/content/DUMPLINGs/protein_context_features
# 2579
# total 4
# drwxr-xr-x 2 root root 4096 May 10 08:52 DUMPLING_A2_first_run_20260510_041820

# %% [markdown]
# ### 12. Final sync back to Drive
# <small>
# В конце мы явно сохраняем:
#
# - `runs/`
# - `esm_cache/`
#
# Почему `esm_cache/` достаточно синкать здесь один раз:
# - эмбеддинги после записи не переписываются,
# - в процессе рана просто могут появиться новые cache-файлы,
# - поэтому финальный sync в нормальном сценарии достаточен.
#
# Это последний шаг сохранения результатов из временного `/content` обратно в долговременное хранилище на **Drive**.
# </small>

# %%
# !bash scripts/colab_finalize_sync.sh \
  "/content/DUMPLINGs/runs" \
  "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/runs" \
  "/content/DUMPLINGs/protein_context_features" \
  "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/protein_context_features"

# %% [markdown]
# ### 13. Stop background sync
# <small>
# После завершения run можно явно остановить фоновый процесс синхронизации <code>runs/</code>.
#
# Это не всегда критично, но полезно, чтобы не оставлять лишний висящий loop в runtime.
# </small>

# %%
sync_proc.terminate()
print("Stopped sync PID:", sync_proc.pid)
# Out:
# Stopped sync PID: 4490
