# %% [markdown]
# ### 0. Runtime sanity check
# <small>
# Эта ячейка нужна для самого первого вопроса: я вообще в правильной среде или нет?
#
# Что она проверяет:
# - текущую рабочую директорию,
# - имя хоста,
# - есть ли **CUDA**,
# - виден ли `/content`,
# - не сижу ли я случайно в локальной машине вместо **Colab** runtime,
# - версию **Python**,
# - версию **Torch**,
# - **CUDA** runtime,
# - имя **GPU**,
# - число доступных **CPU**.
#
# Это просто диагностическая ячейка перед любыми действиями.
# Если здесь нет **GPU** или нет `/content`, дальше запускать пайплайн бессмысленно.
# </small>

# %%
import os, sys, socket, torch, pathlib, shutil, subprocess, textwrap
print("cwd:", os.getcwd())
print("host:", socket.gethostname())
print("cuda:", torch.cuda.is_available())
print("content exists:", pathlib.Path("/content").exists())
print("local project exists:", pathlib.Path("/home/yaroslav").exists())
print("Python:", sys.version)
print("Executable:", sys.executable)
print("Torch version:", torch.__version__)
print("CUDA version :", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("CPU cores visible:", os.cpu_count())
# Out:
# cwd: /content
# host: cb3928b00c3b
# cuda: True
# content exists: True
# local project exists: False
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Executable: /usr/bin/python3
# Torch version: 2.10.0+cu128
# CUDA version : 12.8
# CUDA available: True
# GPU name: Tesla T4
# CPU cores visible: 2

# %% [markdown]
# ### 1. Mount Google Drive
# <small>
# Проектовый репозиторий, старые <code>runs/</code>, архив **PDBBind** и <code>esm_cache/</code> лежат на **Google Drive**.
#
# Эта ячейка просто подключает **Drive** к runtime, чтобы дальше можно было:
# - подтянуть свежий код,
# - скопировать нужные файлы в `/content`,
# - потом вернуть артефакты обратно на **Drive**.
#
# Важно: тренировка идет не на **Drive**, а в `/content`.
# **Drive** здесь используется как долговременное хранилище, а не как рабочая файловая система для обучения.
# </small>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. Imports for notebook orchestration
# <small>
# Здесь только те импорты, которые нужны самому ноутбуку как "пульту управления":
#
# - менять директории,
# - запускать фоновые процессы,
# - смотреть версию **Torch**.
#
# Логика обучения, датасетов и моделей здесь не живет.
# Она уже вынесена в проектные файлы и в `scripts/`.
# </small>

# %%
import os
import subprocess
import torch

# %% [markdown]
# ### 3. Define paths and refresh the Drive-side repo
# <small>
# Здесь задаются две важные директории:
#
# - `SRC` — репозиторий на **Google Drive**,
# - `DST` — временная рабочая копия в `/content`.
#
# Почему так:
# - код и обучение лучше держать в `/content`, потому что это быстрее и стабильнее,
# - **Drive** остается местом хранения, а не местом активной работы.
#
# Также здесь делается:
# - переход в `SRC`,
# - `git checkout -- config.json` чтобы сбросить временные правки в конфиге,
# - `git pull` чтобы подтянуть свежий код.
#
# Смысл простой: на **Drive** лежит "источник истины", а в `/content` каждый запуск собирается свежая рабочая копия.
# </small>

# %%
SRC = "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs"
DST = "/content/DUMPLINGs"

LOCAL_RUNS = f"{DST}/runs"
DRIVE_RUNS = f"{SRC}/runs"

LOCAL_FEATURES = f"{DST}/protein_context_features"
DRIVE_FEATURES = f"{SRC}/protein_context_features"

os.chdir(SRC)
# !git pull
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 7 (delta 6), reused 7 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 3.38 KiB | 30.00 KiB/s, done.
# From https://github.com/BlackSabbitch/DUMPLINGs
#    3f20aeb..011ef9c  main       -> origin/main
# Updating 3f20aeb..011ef9c
# Fast-forward
#  config.json  |   1 +
#  evaluator.py |  26 +++++--
#  logger.py    |  61 +++++++++++++---
#  main_1.ipynb |  23 +++++-
#  trainer.py   | 226 +++++++++++++++++++++++++++++++++++++++++++++++++++--------
#  5 files changed, 287 insertions(+), 50 deletions(-)

# %% [markdown]
# ### 4. Stage the workspace into `/content`
# <small>
# Это одна из самых важных стадий.
#
# Скрипт:
# - пересоздает рабочую папку `DST`,
# - копирует туда только нужные проектные файлы,
# - копирует `esm_cache/`, если он уже есть на **Drive**,
# - копирует архив `pdbbind_v2016.tar.gz`.
#
# Зачем это нужно:
# - не работать напрямую из **Google Drive**,
# - не тянуть за собой весь возможный мусор,
# - иметь чистую воспроизводимую рабочую копию на каждый run.
#
# То есть после этой ячейки `/content/DUMPLINGs` — это реальное место, из которого будет запускаться эксперимент.
# </small>

# %%
# !python scripts/colab_stage_workspace.py \
  --src "{SRC}" \
  --dst "{DST}" \
  --drive-runs "{DRIVE_RUNS}"
# Out:
# Copied protein context features from /content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/protein_context_features (2579 top-level entries, source=protein_context_features)
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/scripts/colab_stage_workspace.py", line 114, in <module>
#     main()
#   File "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/scripts/colab_stage_workspace.py", line 108, in main
#     stage_archive(src_root, dst_root, args.archive_name)
#   File "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/scripts/colab_stage_workspace.py", line 75, in stage_archive
#     shutil.copy2(archive_src, archive_dst)
#   File "/usr/lib/python3.12/shutil.py", line 475, in copy2
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#   File "/usr/lib/python3.12/shutil.py", line 273, in copyfile
#     _fastcopy_sendfile(fsrc, fdst)
#   File "/usr/lib/python3.12/shutil.py", line 150, in _fastcopy_sendfile
#     sent = os.sendfile(outfd, infd, offset, blocksize)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %% [markdown]
# ### 5. Enter the staged workspace
# <small>
# После копирования мы явно переходим в <code>DST</code>.
#
# Это важно, потому что дальше:
# - `run.sh`,
# - `run.py`,
# - относительные пути вроде `datasets/`, `runs/`, `esm_cache/`
#
# должны разрешаться именно внутри `/content/DUMPLINGs`, а не где-то еще.
# </small>

# %%
os.chdir(DST)
print(os.getcwd())
# Out:
# /content/DUMPLINGs

# %% [markdown]
# ### 6. Install ordinary project requirements
# <small>
# Эта ячейка ставит обычные зависимости проекта из <code>requirements.txt</code>.
#
# Сюда относятся, например:
# - `pandas`
# - `tqdm`
# - `matplotlib`
# - `biopython`
# - `rdkit`
# - `fair-esm`
# - `uniplot`
#
# Почему это вынесено в отдельный шаг:
# - это обычные project dependencies,
# - они логически отличаются от **PyG/Torch-Geometric** стека,
# - их удобнее диагностировать отдельно.
#
# Важно: здесь не ставится специальный **CUDA/PyG** стек.
# Он ставится следующим шагом отдельным скриптом, потому что там нужна привязка к конкретным версиям **Torch** и **CUDA** в **Colab** runtime.
# </small>

# %%
# !python scripts/colab_install_requirements.py
# Out:
# Requirements file: requirements.txt
# Skipping prefixes:
#   - torch
#   - torch-geometric
#   - torch-scatter
#   - torch-sparse
#   - torch-cluster
#   - pyg-lib
# Installing filtered requirements:
#   - rdkit
#   - biopython
#   - pandas
#   - tqdm
#   - matplotlib
#   - uniplot
#   - fair-esm
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2026.3.1)
# Requirement already satisfied: biopython in /usr/local/lib/python3.12/dist-packages (1.87)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: uniplot in /usr/local/lib/python3.12/dist-packages (0.21.5)
# Requirement already satisfied: fair-esm in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: readchar>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from uniplot) (4.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ### 7. Install Colab-specific PyG dependencies
# <small>
# Эта стадия не про сам проект, а про среду выполнения.
#
# Скрипт:
# - определяет текущую версию **Torch** и **CUDA** в runtime,
# - подбирает правильный wheel index для **PyG**,
# - сносит потенциально несовместимые старые пакеты,
# - ставит совместимые `pyg-lib`, `torch-scatter`, `torch-sparse`, `torch-cluster`, `torch-geometric`,
# - делает небольшую проверку, что **CUDA**-часть действительно работает.
#
# Это именно **Colab** bootstrap.
# В обычной локальной среде такой шаг может не понадобиться.
# </small>

# %%
# !python scripts/colab_install_pyg.py
# Out:
# PyG wheel index: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# $ pip uninstall -y pyg-lib torch-scatter torch-sparse torch-cluster torch-geometric || true
# Found existing installation: pyg_lib 0.6.0+pt210cu128
# Uninstalling pyg_lib-0.6.0+pt210cu128:
#   Successfully uninstalled pyg_lib-0.6.0+pt210cu128
# Found existing installation: torch_scatter 2.1.2+pt210cu128
# Uninstalling torch_scatter-2.1.2+pt210cu128:
#   Successfully uninstalled torch_scatter-2.1.2+pt210cu128
# Found existing installation: torch_sparse 0.6.18+pt210cu128
# Uninstalling torch_sparse-0.6.18+pt210cu128:
#   Successfully uninstalled torch_sparse-0.6.18+pt210cu128
# Found existing installation: torch_cluster 1.6.3+pt210cu128
# Uninstalling torch_cluster-1.6.3+pt210cu128:
#   Successfully uninstalled torch_cluster-1.6.3+pt210cu128
# Found existing installation: torch-geometric 2.7.0
# Uninstalling torch-geometric-2.7.0:
#   Successfully uninstalled torch-geometric-2.7.0
# $ pip install pyg-lib torch-scatter torch-sparse torch-cluster -f https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Looking in links: https://data.pyg.org/whl/torch-2.10.0+cu128.html
# Collecting pyg-lib
#   Using cached https://data.pyg.org/whl/torch-2.10.0%2Bcu128/pyg_lib-0.6.0%2Bpt210cu128-cp312-cp312-manylinux_2_28_x86_64.whl (49.9 MB)
# Collecting torch-scatter
#   Using cached https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_scatter-2.1.2%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (10.9 MB)
# Collecting torch-sparse
#   Using cached https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_sparse-0.6.18%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (5.4 MB)
# Collecting torch-cluster
#   Using cached https://data.pyg.org/whl/torch-2.10.0%2Bcu128/torch_cluster-1.6.3%2Bpt210cu128-cp312-cp312-linux_x86_64.whl (3.5 MB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch-sparse) (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from scipy->torch-sparse) (2.0.2)
# Installing collected packages: torch-scatter, pyg-lib, torch-sparse, torch-cluster
# Successfully installed pyg-lib-0.6.0+pt210cu128 torch-cluster-1.6.3+pt210cu128 torch-scatter-2.1.2+pt210cu128 torch-sparse-0.6.18+pt210cu128
# $ pip install torch-geometric
# Collecting torch-geometric
#   Using cached torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.13.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric) (1.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch-geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric) (2026.4.22)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.15.0)
# Using cached torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.7.0
# torch_sparse: /usr/local/lib/python3.12/dist-packages/torch_sparse/__init__.py
# torch_sparse CUDA check OK: cuda:0
#
# Recommended Colab workflow:
# 1. Keep the repo and training outputs in /content while running.
# 2. Copy final runs/ and cached artifacts back to Drive after training.
# 3. Avoid heavy read/write loops directly on mounted Google Drive.

# %% [markdown]
# ### 8. Re-check Torch and CUDA after dependency setup
# <small>
# После установки **PyG** полезно еще раз увидеть:
#
# - что **Torch** жив,
# - что **CUDA** по-прежнему доступна,
# - что версия **CUDA** выглядит ожидаемо.
#
# Это не обязательная ячейка, но удобная контрольная точка, если потом что-то идет странно.
# </small>

# %%
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("cuda version:", torch.version.cuda)
# Out:
# torch: 2.10.0+cu128
# cuda available: True
# cuda version: 12.8

# %% [markdown]
# ### 9. Start background sync for `runs/`
# <small>
# Во время обучения <code>runs/</code> стоит периодически синкать обратно на **Drive**.
#
# Зачем:
# - если runtime упадет,
# - если браузер/сессия отвалится,
# - если **Colab** решит закончить жизнь раньше, чем хотелось,
#
# то хотя бы часть логов и артефактов уже будет на **Drive**.
#
# Почему здесь синкается только `runs/`, а не `esm_cache/`:
# - `runs/` постоянно пополняется логами, history, checkpoint-ами,
# - `esm_cache/` в обычной жизни достаточно:
#   - скопировать в начале,
#   - и один раз вернуть в конце.
#
# То есть `runs/` — это живой поток артефактов,
# а `esm_cache/` — накопительный кэш, который обычно не требует постоянной синхронизации.
# </small>

# %%
sync_proc = subprocess.Popen([
    "bash",
    "scripts/colab_start_sync.sh",
    LOCAL_RUNS,
    DRIVE_RUNS,
])
print("Sync PID:", sync_proc.pid)
# Out:
# Sync PID: 19953

# %% [markdown]
# ### 10. Launch the experiment
# <small>
# Это уже собственно запуск проекта.
#
# Мы:
# - делаем `run.sh` исполняемым,
# - запускаем его с `--extract`.
#
# Что означает `--extract`:
# - перед построением датасета будет выполнена распаковка/подготовка исходного архива.
#
# Если extraction не нужен, можно запускать просто `./run.sh`.
#
# Важно: к этому моменту весь подготовительный orchestration уже должен быть завершен.
# После этой ячейки начинает работать сам проектный pipeline.
# </small>

# %%
# !chmod +x run.sh
# !./run.sh --extract
# Out:
# [INFO][EXPERIMENT] Starting experiment: DUMPLING_A15_esm_DimeNet
# [INFO][EXPERIMENT] ============================================= *** STAGE: INITIALIZING *** ==============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Experiment signature: DUMPLING_A15_esm_DimeNet_20260507_195111
# [INFO][EXPERIMENT] Base Datasets folder: datasets
# [INFO][EXPERIMENT] Base protein context features folder: protein_context_features
# [INFO][EXPERIMENT] Run results folder: runs/DUMPLING_A15_esm_DimeNet_20260507_195111
# [INFO][EXPERIMENT] Log file: runs/DUMPLING_A15_esm_DimeNet_20260507_195111/log.txt
# [INFO][EXPERIMENT] ================================================ *** STAGE: DATASET *** ================================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][InteractionGraphParser] Initialized dist_threshold=5.0, ca_only=False
# [INFO][CNNParser] Initialized is_ligand=False
# [INFO][REGISTRY] Loaded bad complexes registry from bad_complexes.toml with 1 entries
# [INFO][EXPERIMENT] Preparing extraction for subset 'refined'.
# [INFO][EXTRACTION] Unpacking 4057 complexes.
# Extracting refined: 66444file [00:57, 1152.07file/s]
# [DEBUG][EXTRACTION] Unpacking completed.
# [DEBUG][EXPERIMENT] Extraction for subset 'refined' completed in 1m 45.2s
# [INFO][EXPERIMENT] Preparing dataset build for subset 'refined'.
# [WARNING][REGISTRY] Excluded 1 complexes from subset refined using bad_complexes.toml: 4bps(training)
# [INFO][BUILD] Starting parallel parsing on 2 cores.
# 100%|██████████| 4056/4056 [02:19<00:00, 29.17it/s]
# [INFO][BUILD] Success: 4056, Errors: 0
# [INFO][SAVE] Dataset saved to datasets/pdbbds_ref_duoNE_c4c7540228cdf199b68bbda99a18e4f4.pickle (compression: None)
# [INFO][SAVE] Metadata saved to datasets/pdbbds_ref_duoNE_c4c7540228cdf199b68bbda99a18e4f4_meta.json
# [DEBUG][EXPERIMENT] Dataset build for subset 'refined' completed in 2m 39.0s
# [INFO][SPLIT] Preparing train/val/test split.
# [INFO][SPLIT] Core as test: True
# [INFO][SPLIT] Strategy: random
# [DEBUG][SPLIT] Total: 3766 | Train: 3202 | Val: 564
# [DEBUG][SPLIT] Train/val/test split completed in 0.0s
# [INFO][EXPERIMENT] Prepared splits | Train: 3202 | Val: 564 | Test: 290
# [INFO][NORMALIZATION] Preparing data normalization.
# [DEBUG][NORMALIZATION] Data normalization completed in 0.0s
# [INFO][NORMALIZATION] Data Stats: {'mean': 6.401942535915053, 'std': 1.9791400063456517}
# [INFO][NORMALIZATION] min value: -2.224169347191835, max value: 2.7881086969050095
# [DEBUG][CHECK] Performing quick data checks on the first training sample.
# [DEBUG][CHECK] ID комплекса: 3ujb
# [DEBUG][CHECK] Атомов в графе: 532
# [DEBUG][CHECK] Размерность признаков: 4
# [DEBUG][CHECK] Наличие координат (pos): True
# [INFO][DATA_QUALITY] Data quality registry active: bad_complexes.toml (1 entries)
# [INFO][EXPERIMENT] Dataset preparation finished in 4m 24.2s
# [INFO][EXPERIMENT] ============================================== *** STAGE: ENRICHMENT *** ===============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Preparing training datasets and loaders.
# [INFO][PROTEIN_CONTEXT] Preparing protein context embedding precompute: mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, batch_size=8, cache_path=protein_context_features
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'train' with 3202 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'train' completed in 1.9s (unique=2131, cached_before=2131, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'val' with 564 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'val' completed in 0.2s (unique=481, cached_before=481, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Preparing protein context precompute for split 'test' with 290 sequences.
# [DEBUG][PROTEIN_CONTEXT] Protein context precompute for split 'test' completed in 0.1s (unique=220, cached_before=220, computed_now=0)
# [DEBUG][PROTEIN_CONTEXT] Protein context embedding precompute completed in 22.7s (split_unique_total=2832, cached_before_total=2832, computed_now_total=0)
# [INFO][PROTEIN_CONTEXT] Preparing protein context prewarm: mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, repr_layer=33, pooling=mean, cache_path=protein_context_features
# [DEBUG][PROTEIN_CONTEXT] Protein context encoder weights are warmed up in 20.8s.
# [INFO][PROTEIN_CONTEXT] Protein context settings -> mode=esm_frozen_whole, model=esm2_t33_650M_UR50D, repr_layer=33, pooling=mean, cache_path=protein_context_features, max_length=1022
# [INFO][EXPERIMENT] ============================================= *** STAGE: RUN SETTINGS *** ==============================================
# [INFO][EXPERIMENT] ========================================================================================================================
# [INFO][EXPERIMENT] Run settings -> source_subset=refined, core_as_test=True, splitter=random, batch_size=2, num_workers=2, splitter_seed=42, epochs=100
# [INFO][MODEL] DimeNet settings -> hidden_channels=128, cutoff=5.0, max_num_neighbors=12, num_blocks=3, ca_only=False, protein_context=esm_frozen_whole
# [INFO][OPTIMIZER] Optimizer settings -> type=AdamW, lr=0.0001, weight_decay=0.01
# [INFO][MODEL] Preparing model initialization.
# [DEBUG][MODEL] Model initialization completed in 27.4s
# [INFO][EXPERIMENT] Launch on: cuda
# [DEBUG][DEBUG] --- FULL MODEL PARAMETERS SCAN ---
# [DEBUG][OPTIMIZER] Name: gnn.rbf.freq | Shape: [6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.emb.emb.weight | Shape: [95, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.emb.lin_rbf.weight | Shape: [128, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.emb.lin_rbf.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.emb.lin.weight | Shape: [128, 384] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.emb.lin.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lin_rbf.weight | Shape: [128, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lin_up.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.0.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.0.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lins.2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.0.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lin_rbf.weight | Shape: [128, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lin_up.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.0.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.0.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lins.2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.1.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lin_rbf.weight | Shape: [128, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lin_up.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.0.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.0.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lins.2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.2.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lin_rbf.weight | Shape: [128, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lin_up.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.0.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.0.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lins.2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.output_blocks.3.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_rbf1.weight | Shape: [8, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_rbf2.weight | Shape: [128, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_sbf1.weight | Shape: [8, 42] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_sbf2.weight | Shape: [64, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_kj.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_kj.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_ji.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_ji.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_down.weight | Shape: [64, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin_up.weight | Shape: [128, 64] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_before_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_before_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_before_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_before_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.lin.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.1.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.1.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.1.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.0.layers_after_skip.1.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_rbf1.weight | Shape: [8, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_rbf2.weight | Shape: [128, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_sbf1.weight | Shape: [8, 42] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_sbf2.weight | Shape: [64, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_kj.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_kj.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_ji.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_ji.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_down.weight | Shape: [64, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin_up.weight | Shape: [128, 64] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_before_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_before_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_before_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_before_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.lin.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.1.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.1.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.1.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.1.layers_after_skip.1.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_rbf1.weight | Shape: [8, 6] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_rbf2.weight | Shape: [128, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_sbf1.weight | Shape: [8, 42] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_sbf2.weight | Shape: [64, 8] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_kj.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_kj.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_ji.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_ji.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_down.weight | Shape: [64, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin_up.weight | Shape: [128, 64] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_before_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_before_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_before_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_before_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.lin.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.0.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.0.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.0.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.0.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.1.lin1.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.1.lin1.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.1.lin2.weight | Shape: [128, 128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: gnn.interaction_blocks.2.layers_after_skip.1.lin2.bias | Shape: [128] | RequiresGrad: True
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.embed_tokens.weight | Shape: [33, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.0.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.1.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.2.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.3.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.4.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.5.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.6.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.7.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.8.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.9.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.10.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.11.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.12.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.13.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.k_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.v_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.v_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.q_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.q_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.out_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn.out_proj.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.self_attn_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.fc1.weight | Shape: [5120, 1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.fc1.bias | Shape: [5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.fc2.weight | Shape: [1280, 5120] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.fc2.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.final_layer_norm.weight | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.14.final_layer_norm.bias | Shape: [1280] | RequiresGrad: False
# [DEBUG][OPTIMIZER] Name: protein_context_encoder.model.layers.15.self_attn.k_proj.weight | Shape: [1280, 1280] | RequiresGrad: False
# ...
# │                   ▖ ▘                                                          │
# │                            ▝                                                   │
# │         ▝ ▝   ▘      ▝                                                         │
# │                                                                                │ 0.70
# │                                                                                │
# │                                                                                │
# │     ▝                                                                          │
# │    ▖  ▝                                                                        │
# │             ▝                                                                  │
# │  ▖                                                                             │
# │                                                                                │ 0.65
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │ 0.60
# │                                                                                │
# │▖                                                                               │
# └────────────────────────────────────────────────────────────────────────────────┘
#                  10                 20                 30                 40
# [INFO][SUMMARY] Concordancy Index Curve:
#                               Ranking Accuracy (CI)
# ┌────────────────────────────────────────────────────────────────────────────────┐
# │                                         ▗ ▝ ▝           ▖  ▝     ▘     ▖ ▖     │
# │                                        ▘        ▖ ▖ ▘ ▘  ▝   ▗ ▝   ▘ ▘    ▝ ▝ ▝│ 0.78
# │                              ▝ ▖              ▝                                │
# │                                    ▖                                           │
# │                        ▗             ▘                                         │
# │                 ▘ ▖ ▖    ▝       ▘                                             │
# │           ▗   ▖                                                                │
# │         ▗                  ▝                                                   │
# │                                                                                │
# │                      ▝                                                         │ 0.75
# │                                                                                │
# │     ▗                                                                          │
# │                                                                                │
# │    ▘  ▝     ▝                                                                  │
# │                                                                                │
# │  ▖                                                                             │
# │                                                                                │
# │                                                                                │ 0.73
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │                                                                                │
# │▖                                                                               │
# └────────────────────────────────────────────────────────────────────────────────┘
#                  10                 20                 30                 40
# [INFO][SUMMARY] Actual vs Predicted Scatter Plot:
#                               Predicted = f(Actual)
# ┌────────────────────────────────────────────────────────────────────────────────┐
# │                                                                            ▝▗▄▀│
# │                                                                          ▄▞▀▘  │
# │                                                                       ▄▞▀      │
# │                                                              ▘  ▝ ▗▄▀▀ ▌    ▝  │
# │                                                   ▗  ▘         ▗▄▀▘▘  ▖      ▗ │ 10
# │                                                 ▖ ▘▖     ▗  ▄▞▀▘ ▖ ▗  ▘        │
# │                                               ▞     ▗▗ ▖ ▄▞▀         ▝  ▝▗     │
# │                          ▗            ▗         ▗▖ ▄▝▗▄▀▀▌ ▘▄  ▘               │
# │               ▖       ▖           ▝▖   ▘   ▀▞▖▚ ▘▝▗▄▀▘▗▘  ▘  ▝   ▗▘    ▀       │
# │                          ▗       ▗▞ ▗ ▖▚▝▙  ▗▖ ▄▞▀▘ ▝  ▗   ▘▘                  │ 8
# │                       ▗   ▘▘ ▘    ▝▄ ▘ ▞▗▀▀▌▄▞▀▌▘▟ ▛▛ ▘▖▗ ▘                    │
# │                         ▗▖  ▝▘▖ ▘▌▛▙ ▐  ▗▄▀▀ ▖▗▘▖ ▝  ▝▘  ▚▘▗▝▝                 │
# │           ▘     ▗ ▄       ▗▖▝ ▗▄ ▜ ▞▛▗▄▀▘ ▟▞▝▝ ▗▖ ▖▘▖   ▚  ▘▖                  │
# │       ▘   ▘       ▄▗ ▘ ▘  ▗▘▚▜ ▟▘▀▄▄▀▘▚▌▄▀█ ▐ ▀▙▛   ▗▗▘      ▝     ▗           │
# │        ▝    ▖ ▟ ▖  ▝▘ ▘▄▀▙▝▘ ▖ ▄▞▀▗ ▛▄▟▚▖▝▗ ▙█     ▌                           │ 6
# │           ▘  ▖▐▗ ▘ ▐▛▝▗▄ ▝▖▗▄▞▀▌▖▝▀▝▟ ▗▘▖▖▗▝  ▘▖                               │
# │         ▝  ▛  ▖    ▖▚ ▝ ▗▄▀▘▙▘▐▗▖▝▗  ▝  ▗▖  ▗                 ▖                │
# │  ▚     ▝ ▖▗▝▞ ▗▀▟  ▘▚▄▄▀▘▖▝    ▗   ▖     ▘▝▖   ▘               ▘               │
# │       ▗▞▖  ▘▗▄▘▗  ▄▞▀  ▝▘ ▝▗ ▚▖   ▖▗▗             ▘                            │
# │ ▗▝ ▖▗   ▗▌▖▄▗ ▗▄▞▀▄ ▖   ▞▘ ▝▘ ▜     ▘    ▌                             ▘       │ 4
# │   ▗  ▝▗▞▌▗█▗▄▀▘ ▗▖   ▖   ▘▝▝                                                   │
# │    ▙   ▗▄▄▀▘ ▀     ▝           ▝ ▝                                             │
# │  ▗▖ ▖▄▞▀   ▘                                                                   │
# │  ▗▄▞▀  ▘                                                                       │
# │▄▀▘ ▗                                                                           │ 2
# └────────────────────────────────────────────────────────────────────────────────┘
#  2               4               6               8              10
# [INFO][SUMMARY] Errors Distribution (Residuals):
#                               Residuals Distribution
# ┌────────────────────────────────────────────────────────────────────────────────┐
# │                                               │▗▄▀▖                            │
# │                                              ▗▞▘  ▝▚▖                          │
# │                                         ▗▞▀▀▀▘│     ▝▄                         │
# │                                         ▞     │      ▐                         │
# │                                        ▗▘     │       ▌                        │ 80
# │                                        ▞      │       ▐                        │
# │                                       ▗▘      │       ▝▖                       │
# │                                       ▌       │        ▌                       │
# │                                      ▐        │        ▐                       │
# │                                     ▗▌        │         ▌                      │ 60
# │                                     ▞         │         ▚                      │
# │                                    ▗▘         │         ▐                      │
# │                                    ▌          │          ▌                     │
# │                                   ▞           │          ▐                     │
# │                                  ▗▘           │          ▝▌                    │ 40
# │                                  ▌            │           ▝▖                   │
# │                                 ▞             │            ▝▖                  │
# │                               ▗▀              │             ▝▖                 │
# │                              ▗▘               │              ▝▖                │
# │                             ▟▘                │               ▝▖               │ 20
# │                           ▗▞                  │                ▝▖              │
# │                          ▗▘                   │                 ▝▖             │
# │                        ▗▞▘                    │                  ▝▄            │
# │                      ▗▞▘                      │                    ▀▀▄▄▄▄▄▄    │
# │▀▄▄▄▄▄▄▄▀▀▀▀▀▀▀▀▀▀▀▀▀▀▘▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁│▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▀▀▀▀│ 0
# └────────────────────────────────────────────────────────────────────────────────┘
#    -6             -4            -2              0             2              4
# [INFO][SUMMARY] Generating Multi-column ASCII Dashboard.
# [INFO][SUMMARY]
# Learning Curve (Loss)                                                             Validation RMSE
# ▘=Train Loss  *=Val Loss                                        ┌──────────────────────────────────────────────────┐
# +------------------------------------------------+              │   ▝                                              │
# |▘  *                                            | 0.3687       │                                                  │ 1.8
# |*   *   *                                       |              │▖                                                 │
# | ▘                                              |              │     ▖  ▝                                         │
# |  ▘▘  **                                        | 0.2781       │                                                  │
# |    ▘ ▘▘ ***** ***  ***                         |              │                                                  │
# |        ▘▘        **    ********* ******** *****|              │ ▖                                                │
# |          ▘▘▘▘                                  | 0.1875       │                                                  │
# |               ▘▘▘                              |              │  ▗    ▖                                          │
# |                  ▘▘▘▘                          |              │      ▖                                           │
# |                      ▘ ▘                       | 0.0969       │              ▖ ▗                                 │ 1.5
# |                         ▘▘▘▘                   |              │         ▝  ▘▘ ▗ ▝   ▘ ▗                          │
# |                             ▘▘▘▘ ▘▘            |              │          ▝           ▗                           │
# |                                    ▘▘▘▘▘▘ ▘▘▘▘▘| 0.0063       │                   ▖▘    ▘      ▖                 │
# +------------------------------------------------+              │                          ▘▘▝▝▝  ▘▖▝▝▗ ▘▘▘▝▝▗ ▖▘▝▝│
# 1                                             43                └──────────────────────────────────────────────────┘
#                                                                           10          20          30          40
# [INFO][SUMMARY]
#               Correlation (Pearson R)                                          Ranking Accuracy (CI)
# ┌──────────────────────────────────────────────────┐            ┌──────────────────────────────────────────────────┐
# │                         ▖▖▖▝▗▗ ▖▖▘▝▗▝ ▖▖▘▗▗▝ ▘▖▗▗│            │                         ▖▖▘▝    ▖▖▝▗▝  ▖▘▗▗▗ ▖▖▗▗│
# │                   ▘▖                             │            │                   ▘▖        ▝▝ ▘      ▘          │
# │          ▗    ▗▝    ▖▝▗                          │            │                      ▝▝                          │
# │            ▖▘   ▗                                │            │          ▝ ▖▖ ▝▝    ▘                            │ 0.76
# │      ▘▘ ▝    ▖                                   │            │      ▖▘ ▝       ▝                                │
# │                                                  │ 0.7        │              ▖                                   │
# │   ▗                                              │            │                                                  │
# │  ▗  ▘  ▗                                         │            │   ▝ ▖  ▗                                         │ 0.74
# │ ▖                                                │            │  ▝                                               │
# │                                                  │            │ ▘                                                │
# │                                                  │            │                                                  │
# │                                                  │            │                                                  │ 0.72
# │                                                  │            │                                                  │
# │                                                  │ 0.6        │                                                  │
# │▖                                                 │            │▖                                                 │
# └──────────────────────────────────────────────────┘            └──────────────────────────────────────────────────┘
#           10          20          30          40                          10          20          30          40
# [INFO][SUMMARY] Final Performance Analytics:
#                 Actual vs Predicted                                            Residuals Distribution
# ┌──────────────────────────────────────────────────┐            ┌──────────────────────────────────────────────────┐
# │                                               ▄▄▀│            │                             ▗▄▀▄                 │
# │                                      ▗ ▗   ▄▞▀   │            │                          ▄▞▀▘   ▚▖               │
# │                                ▖▗      ▗▄▀▀▞▘  ▚ │ 10         │                         ▐   │    ▌               │
# │                             ▗▗ ▚   ▗▄▞▀▘▖▗ ▞ ▖   │            │                         ▌   │    ▐               │
# │                ▗       ▗▖ ▗ ▘▗▖▗▗▄▀▀▗▄▖▘▗    ▝   │            │                        ▞    │     ▌              │
# │         ▘    ▘ ▗    ▗▛▗▗▌▄▝▜▀▄▄▀▘▝  ▀▖▘ ▝   ▘    │            │                       ▗▘    │     ▚              │
# │              ▝ ▖▀▐ ▗▟█▀▖▌▗▄▞▀█▀▞▛▟▘▌▌▗▖          │            │                       ▞     │     ▝▖             │
# │      ▝▖  ▗▗▖ ▖▖▘▄▐▟▄▜▐▗▄▀▘█▝▜▟ ▞▖▗▝▞▝▖▖          │            │                      ▞      │      ▌             │ 50
# │    ▝▘  ▖▟▄ ▀▖▞▄▄▙▚▘▄▞▀▘██▐▌█▞▀▘▐▝▘       ▝       │            │                     ▗▘      │      ▝▖            │
# │      ▖▚ ▜▘▘▝█▐▚▗▄▀▀▜▐▀▀▞▜▌▘▚▝▘        ▗          │            │                     ▌       │       ▝▖           │
# │ ▚   ▐▗▞▛▗▛▌▝▄▄▀▘▛▚ ▐ ▀  ▝▘▚  ▘ ▖       ▘         │ 5          │                   ▗▀        │        ▝▖          │
# │ ▄▗▗ ▀▄▟▟▗▄▞▀▌ ▗▌▟▖▜  ▀▞  ▖                  ▘    │            │                  ▄▘         │         ▝▖         │
# │  ▚ ▀▀▄▄▀▘ ▘ ▞   ▝  ▗▗                            │            │                ▗▞           │          ▝▖        │
# │ ▐▞▄▞▀ ▀                                          │            │              ▗▄▘            │           ▐▄▖      │
# │▄▀▀▖                                              │            │▄▄▄▄▄▄▄▄▄▄▄▄▄▞▘▁▁▁▁▁▁▁▁▁▁▁▁▁▁│▁▁▁▁▁▁▁▁▁▁▁▁▁▝▀▀▀▀▀▄│ 0
# └──────────────────────────────────────────────────┘            └──────────────────────────────────────────────────┘
#    2            5           8           10                            -5          -2          0          2
# [INFO][EXPERIMENT] Experiment completed successfully in 1h 46m 58.4s.

# %% [markdown]
# ### 11. Inspect local outputs after the run
# <small>
# Эта ячейка нужна, чтобы быстро посмотреть:
#
# - жив ли `esm_cache/`,
# - сколько там файлов,
# - какие папки появились в `runs/`.
#
# Это просто быстрая sanity-check стадия перед финальным sync обратно на **Drive**.
# </small>

# %%
# !du -sh /content/DUMPLINGs/protein_context_features 2>/dev/null || echo "protein_context_features is absent"
# !find /content/DUMPLINGs/protein_context_features -type f | wc -l
# !ls -lt /content/DUMPLINGs/runs | head
# Out:
# 21M	/content/DUMPLINGs/protein_context_features
# 2579
# total 4
# drwxr-xr-x 2 root root 4096 May  7 21:42 DUMPLING_A15_esm_DimeNet_20260507_195111

# %% [markdown]
# ### 12. Final sync back to Drive
# <small>
# В конце мы явно сохраняем:
#
# - `runs/`
# - `esm_cache/`
#
# Почему `esm_cache/` достаточно синкать здесь один раз:
# - эмбеддинги после записи не переписываются,
# - в процессе рана просто могут появиться новые cache-файлы,
# - поэтому финальный sync в нормальном сценарии достаточен.
#
# Это последний шаг сохранения результатов из временного `/content` обратно в долговременное хранилище на **Drive**.
# </small>

# %%
# !bash scripts/colab_finalize_sync.sh \
  "/content/DUMPLINGs/runs" \
  "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/runs" \
  "/content/DUMPLINGs/protein_context_features" \
  "/content/drive/MyDrive/lisboa_ciencia_de_dados/2_sem/DUMPLINGs/protein_context_features"

# %% [markdown]
# ### 13. Stop background sync
# <small>
# После завершения run можно явно остановить фоновый процесс синхронизации <code>runs/</code>.
#
# Это не всегда критично, но полезно, чтобы не оставлять лишний висящий loop в runtime.
# </small>

# %%
sync_proc.terminate()
print("Stopped sync PID:", sync_proc.pid)
